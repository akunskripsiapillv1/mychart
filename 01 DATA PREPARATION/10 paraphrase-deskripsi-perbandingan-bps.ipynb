# %%
import os
import json
import time
import re
import csv
from typing import Dict, List, Optional
import google.generativeai as genai


def load_output_json(path: str) -> Dict[str, Dict]:
    """
    Load existing output JSON if available, else return empty dict.
    """
    if os.path.exists(path):
        with open(path, 'r', encoding='utf-8') as f:
            return json.load(f)
    return {}


def save_output_json(data: Dict[str, Dict], path: str) -> None:
    """
    Save the output data to JSON file.
    """
    with open(path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

def log_to_csv(log_file: str, filename: str, status: str, count: int):
    header = ['filename', 'status', 'paraphrase_count']
    file_exists = os.path.exists(log_file)

    with open(log_file, 'a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        if not file_exists:
            writer.writerow(header)
        writer.writerow([filename, status, count])

def paraphrase_text(model: genai.GenerativeModel, original_text: str, delay: int = 5, ) -> Optional[List[str]]:
    """
    Use Gemini model to generate 15 paraphrases of the original_text
    following specified guidelines. Returns None on failure.
    """
    prompt = f"""
        Parafrasakan kalimat berikut sebanyak tepat 15 kali tidak kurang dan tidak lebih untuk menghasilkan variasi deskripsi.
        Pastikan output parafrasa memiliki kalimat yang utuh dan tidak rumpang (ditandai dengan akhiran tanda titik).

        Ikuti teknik parafrasa berikut:
        - Parafrasa Ekuivalen: Ganti kata/frasa dengan sinonim yang tepat dan alami.
        - Parafrasa Kontraksi: Ringkas kalimat hanya jika tidak menghilangkan informasi penting atau mengurangi kejelasan.
        - Parafrasa Amplifikasi: Tambahkan detail hanya jika itu memperjelas satuan data spesifik dan sangat jelas tersirat dalam data asli.

        Pertahankan:
        - Gaya penulisan: Gunakan gaya bahasa deskriptif, naratif, dengan konjungsin dan kata keterangan sesuai kaidah bahasa Indonesia yang baik, serta hasilnya tidak jauh mengubah dengan deskripsi asli.
        - Akurasi: Pastikan semua nilai, angka, informasi faktual tetap sama persis, dan disebutkan semuanya.
        - Format: Jangan gunakan markdown, quote, tanda kurung untuk satuan unit, atau format khusus pada hasil parafrasa.
        - Konteks: Deskripsi ini akan digunakan untuk memberikan gambaran utuh terkait sebuah gambar grafik.

        Teks asli: """ + original_text + """
        Hasil Parafrasa:
        1. Parafrasa 1
        2. Parafrasa 2
        dst.
        """
    try:
        response = model.generate_content(prompt)

        if hasattr(response, 'candidates') and response.candidates:
            content = response.candidates[0].content
        if hasattr(content, 'parts') and content.parts:
            text = content.parts[0].text.strip()
        else:
            text = str(content).strip()

        # post-processing respons
        lines = text.strip().split("\n")

        paraphrases = []
        for line in lines:
            line = line.strip()
            if not line:
                continue

            line = re.sub(r'^\s*\[?\d+\.\s*Parafrasa\s*\d+\]?\s*', '', line)
            line = re.sub(r'^\s*\.\s*', '', line)

            if len(line) > 20:  # filter singkat
                paraphrases.append(line)

        if len(paraphrases) < 15:
            message = f"[Warning] Only extracted {len(paraphrases)} paraphrases."
        else:
            message = f"[Success] Extracted {len(paraphrases)} paraphrases."

        print(message)

        return paraphrases
    except Exception as e:
        print(f"[Error] Paraphrasing failed for text '{original_text[:30]}...': {e}")
        return None
    finally:
        time.sleep(delay)

def process_folder(
    input_folder: str,
    output_json: str,
    api_key: str,
    model_name: str = "gemini-2.0-flash",
    delay: int = 5,
    log_file: str = "paraphrase_log_0.2.0.csv"
) -> None:
    """
    Process each .txt file in input_folder, generate paraphrases,
    and save/update output_json incrementally.
    Skips files already processed. On error, does not mark as processed.
        )
    """
    genai.configure(api_key=api_key)
    model = genai.GenerativeModel(model_name)

    data = load_output_json(output_json)

    for fname in os.listdir(input_folder):
        if not fname.lower().endswith('.txt'):
            continue
        key = os.path.splitext(fname)[0]
        if key in data:
            print(f"Skip '{fname}', already processed.")
            continue

        file_path = os.path.join(input_folder, fname)
        with open(file_path, 'r', encoding='utf-8') as f:
            original_text = f.read().strip()

        print(f"Processing '{fname}'...")
        paraphrases = paraphrase_text(model, original_text, delay)

        if paraphrases is None:
            print(f"Skipping save for '{fname}' due to error. Will retry later.")
            log_to_csv(log_file, fname, "Error", 0)
            continue

        count = len(paraphrases)
        status = "Success" if count >= 15 else "Warning"

        data[key] = {
            'original_text': original_text,
            'paraphrases': paraphrases
        }

        save_output_json(data, output_json)
        print(f"Saved paraphrases for '{fname}'.")
        log_to_csv(log_file, fname, status, count)

# %%
process_folder(
    input_folder='base_tambahan_reasoning',
    output_json='paraphrases_tambahan_reasoning.json',
    api_key='API_KEY'
)
# Out:
# Skip 'T0001.txt', already processed.
# Skip 'T0002.txt', already processed.
# Skip 'T0003.txt', already processed.
# Skip 'T0004.txt', already processed.
# Skip 'T0005.txt', already processed.
# Skip 'T0006.txt', already processed.
# Skip 'T0007.txt', already processed.
# Skip 'T0008.txt', already processed.
# Skip 'T0009.txt', already processed.
# Skip 'T0010.txt', already processed.
# Skip 'T0011.txt', already processed.
# Skip 'T0012.txt', already processed.
# Skip 'T0013.txt', already processed.
# Skip 'T0014.txt', already processed.
# Skip 'T0015.txt', already processed.
# Skip 'T0016.txt', already processed.
# Skip 'T0017.txt', already processed.
# Skip 'T0018.txt', already processed.
# Skip 'T0019.txt', already processed.
# Skip 'T0020.txt', already processed.
# Skip 'T0021.txt', already processed.
# Skip 'T0022.txt', already processed.
# Skip 'T0023.txt', already processed.
# Skip 'T0024.txt', already processed.
# Skip 'T0025.txt', already processed.
# Skip 'T0026.txt', already processed.
# Skip 'T0027.txt', already processed.
# Skip 'T0028.txt', already processed.
# Skip 'T0029.txt', already processed.
# Skip 'T0030.txt', already processed.
# Skip 'T0031.txt', already processed.
# Skip 'T0032.txt', already processed.
# Skip 'T0033.txt', already processed.
# Skip 'T0034.txt', already processed.
# Skip 'T0035.txt', already processed.
# Skip 'T0036.txt', already processed.
# Skip 'T0037.txt', already processed.
# Skip 'T0038.txt', already processed.
# Skip 'T0039.txt', already processed.
# Skip 'T0040.txt', already processed.
# Skip 'T0041.txt', already processed.
# Skip 'T0042.txt', already processed.
# Skip 'T0043.txt', already processed.
# Skip 'T0044.txt', already processed.
# Skip 'T0045.txt', already processed.
# Skip 'T0046.txt', already processed.
# Skip 'T0047.txt', already processed.
# Skip 'T0048.txt', already processed.
# Skip 'T0049.txt', already processed.
# Skip 'T0050.txt', already processed.
# Skip 'T0051.txt', already processed.
# Skip 'T0052.txt', already processed.
# Skip 'T0053.txt', already processed.
# Skip 'T0054.txt', already processed.
# Skip 'T0055.txt', already processed.
# Skip 'T0056.txt', already processed.
# Skip 'T0057.txt', already processed.
# Skip 'T0058.txt', already processed.
# Skip 'T0059.txt', already processed.
# Skip 'T0060.txt', already processed.
# Skip 'T0061.txt', already processed.
# Skip 'T0062.txt', already processed.
# Skip 'T0063.txt', already processed.
# Skip 'T0064.txt', already processed.
# Skip 'T0065.txt', already processed.
# Skip 'T0066.txt', already processed.
# Skip 'T0067.txt', already processed.
# Skip 'T0068.txt', already processed.
# Skip 'T0069.txt', already processed.
# Skip 'T0070.txt', already processed.
# Skip 'T0071.txt', already processed.
# Skip 'T0072.txt', already processed.
# Skip 'T0073.txt', already processed.
# Skip 'T0074.txt', already processed.
# Skip 'T0075.txt', already processed.
# Skip 'T0076.txt', already processed.
# Skip 'T0077.txt', already processed.
# Skip 'T0078.txt', already processed.
# Skip 'T0079.txt', already processed.
# Skip 'T0080.txt', already processed.
# Skip 'T0081.txt', already processed.
# Skip 'T0082.txt', already processed.
# Skip 'T0083.txt', already processed.
# Skip 'T0084.txt', already processed.
# Skip 'T0085.txt', already processed.
# Skip 'T0086.txt', already processed.
# Skip 'T0087.txt', already processed.
# Skip 'T0088.txt', already processed.
# Skip 'T0089.txt', already processed.
# Skip 'T0090.txt', already processed.
# Skip 'T0091.txt', already processed.
# Skip 'T0092.txt', already processed.
# Skip 'T0093.txt', already processed.
# Skip 'T0094.txt', already processed.
# Skip 'T0095.txt', already processed.
# Skip 'T0096.txt', already processed.
# Skip 'T0097.txt', already processed.
# Skip 'T0098.txt', already processed.
# Skip 'T0099.txt', already processed.
# Skip 'T0100.txt', already processed.
# Skip 'T0101.txt', already processed.
# Skip 'T0102.txt', already processed.
# Skip 'T0103.txt', already processed.
# Skip 'T0104.txt', already processed.
# Skip 'T0105.txt', already processed.
# Skip 'T0106.txt', already processed.
# Skip 'T0107.txt', already processed.
# Skip 'T0108.txt', already processed.
# Skip 'T0109.txt', already processed.
# Skip 'T0110.txt', already processed.
# Skip 'T0111.txt', already processed.
# Skip 'T0112.txt', already processed.
# Skip 'T0113.txt', already processed.
# Skip 'T0114.txt', already processed.
# Skip 'T0115.txt', already processed.
# Skip 'T0116.txt', already processed.
# Skip 'T0117.txt', already processed.
# Skip 'T0118.txt', already processed.
# Skip 'T0119.txt', already processed.
# Skip 'T0120.txt', already processed.
# Skip 'T0121.txt', already processed.
# Skip 'T0122.txt', already processed.
# Skip 'T0123.txt', already processed.
# Skip 'T0124.txt', already processed.
# Skip 'T0125.txt', already processed.
# Skip 'T0126.txt', already processed.
# Skip 'T0127.txt', already processed.
# Skip 'T0128.txt', already processed.
# Skip 'T0129.txt', already processed.
# Skip 'T0130.txt', already processed.
# Skip 'T0131.txt', already processed.
# Skip 'T0132.txt', already processed.
# Skip 'T0133.txt', already processed.
# Skip 'T0134.txt', already processed.
# Skip 'T0135.txt', already processed.
# Skip 'T0136.txt', already processed.
# Skip 'T0137.txt', already processed.
# Skip 'T0138.txt', already processed.
# Skip 'T0139.txt', already processed.
# Skip 'T0140.txt', already processed.
# Skip 'T0141.txt', already processed.
# Skip 'T0142.txt', already processed.
# Skip 'T0143.txt', already processed.
# Skip 'T0144.txt', already processed.
# Skip 'T0145.txt', already processed.
# Skip 'T0146.txt', already processed.
# Skip 'T0147.txt', already processed.
# Skip 'T0148.txt', already processed.
# Skip 'T0149.txt', already processed.
# Skip 'T0150.txt', already processed.
# Skip 'T0151.txt', already processed.
# Skip 'T0152.txt', already processed.
# Skip 'T0153.txt', already processed.
# Skip 'T0154.txt', already processed.
# Skip 'T0155.txt', already processed.
# Skip 'T0156.txt', already processed.
# Skip 'T0157.txt', already processed.
# Skip 'T0158.txt', already processed.
# Skip 'T0159.txt', already processed.
# Skip 'T0160.txt', already processed.
# Skip 'T0161.txt', already processed.
# Skip 'T0162.txt', already processed.
# Skip 'T0163.txt', already processed.
# Skip 'T0164.txt', already processed.
# Skip 'T0165.txt', already processed.
# Skip 'T0166.txt', already processed.
# Skip 'T0167.txt', already processed.
# Skip 'T0168.txt', already processed.
# Skip 'T0169.txt', already processed.
# Skip 'T0170.txt', already processed.
# Skip 'T0171.txt', already processed.
# Skip 'T0172.txt', already processed.
# Skip 'T0173.txt', already processed.
# Skip 'T0174.txt', already processed.
# Skip 'T0175.txt', already processed.
# Skip 'T0176.txt', already processed.
# Skip 'T0177.txt', already processed.
# Skip 'T0178.txt', already processed.
# Skip 'T0179.txt', already processed.
# Skip 'T0180.txt', already processed.
# Skip 'T0181.txt', already processed.
# Skip 'T0182.txt', already processed.
# Skip 'T0183.txt', already processed.
# Skip 'T0184.txt', already processed.
# Skip 'T0185.txt', already processed.
# Skip 'T0186.txt', already processed.
# Skip 'T0187.txt', already processed.
# Skip 'T0188.txt', already processed.
# Skip 'T0189.txt', already processed.
# Skip 'T0190.txt', already processed.
# Skip 'T0191.txt', already processed.
# Skip 'T0192.txt', already processed.
# Skip 'T0193.txt', already processed.
# Skip 'T0194.txt', already processed.
# Skip 'T0195.txt', already processed.
# Skip 'T0196.txt', already processed.
# Skip 'T0197.txt', already processed.
# Skip 'T0198.txt', already processed.
# Skip 'T0199.txt', already processed.
# Skip 'T0200.txt', already processed.
# Skip 'T0201.txt', already processed.
# Skip 'T0202.txt', already processed.
# Skip 'T0203.txt', already processed.
# Skip 'T0204.txt', already processed.
# Skip 'T0205.txt', already processed.
# Skip 'T0206.txt', already processed.
# Skip 'T0207.txt', already processed.
# Skip 'T0208.txt', already processed.
# Skip 'T0209.txt', already processed.
# Skip 'T0210.txt', already processed.
# Skip 'T0211.txt', already processed.
# Skip 'T0212.txt', already processed.
# Skip 'T0213.txt', already processed.
# Skip 'T0214.txt', already processed.
# Skip 'T0215.txt', already processed.
# Skip 'T0216.txt', already processed.
# Skip 'T0217.txt', already processed.
# Skip 'T0218.txt', already processed.
# Skip 'T0219.txt', already processed.
# Skip 'T0220.txt', already processed.
# Skip 'T0221.txt', already processed.
# Skip 'T0222.txt', already processed.
# Skip 'T0223.txt', already processed.
# Skip 'T0224.txt', already processed.
# Skip 'T0225.txt', already processed.
# Skip 'T0226.txt', already processed.
# Skip 'T0227.txt', already processed.
# Skip 'T0228.txt', already processed.
# Skip 'T0229.txt', already processed.
# Skip 'T0230.txt', already processed.
# Skip 'T0231.txt', already processed.
# Skip 'T0232.txt', already processed.
# Skip 'T0233.txt', already processed.
# Skip 'T0234.txt', already processed.
# Skip 'T0235.txt', already processed.
# Skip 'T0236.txt', already processed.
# Skip 'T0237.txt', already processed.
# Skip 'T0238.txt', already processed.
# Skip 'T0239.txt', already processed.
# Skip 'T0240.txt', already processed.
# Skip 'T0241.txt', already processed.
# Skip 'T0242.txt', already processed.
# Skip 'T0243.txt', already processed.
# Skip 'T0244.txt', already processed.
# Skip 'T0245.txt', already processed.
# Skip 'T0246.txt', already processed.
# Skip 'T0247.txt', already processed.
# Skip 'T0248.txt', already processed.
# Skip 'T0249.txt', already processed.
# Skip 'T0250.txt', already processed.
# Skip 'T0251.txt', already processed.
# Skip 'T0252.txt', already processed.
# Skip 'T0253.txt', already processed.
# Skip 'T0254.txt', already processed.
# Skip 'T0255.txt', already processed.
# Skip 'T0256.txt', already processed.
# Skip 'T0257.txt', already processed.
# Skip 'T0258.txt', already processed.
# Skip 'T0259.txt', already processed.
# Skip 'T0260.txt', already processed.
# Skip 'T0261.txt', already processed.
# Skip 'T0262.txt', already processed.
# Skip 'T0263.txt', already processed.
# Skip 'T0264.txt', already processed.
# Skip 'T0265.txt', already processed.
# Skip 'T0266.txt', already processed.
# Skip 'T0267.txt', already processed.
# Skip 'T0268.txt', already processed.
# Skip 'T0269.txt', already processed.
# Skip 'T0270.txt', already processed.
# Skip 'T0271.txt', already processed.
# Skip 'T0272.txt', already processed.
# Skip 'T0273.txt', already processed.
# Skip 'T0274.txt', already processed.
# Skip 'T0275.txt', already processed.
# Skip 'T0276.txt', already processed.
# Skip 'T0277.txt', already processed.
# Skip 'T0278.txt', already processed.
# Skip 'T0279.txt', already processed.
# Skip 'T0280.txt', already processed.
# Skip 'T0281.txt', already processed.
# Skip 'T0282.txt', already processed.
# Skip 'T0283.txt', already processed.
# Skip 'T0284.txt', already processed.
# Skip 'T0285.txt', already processed.
# Skip 'T0286.txt', already processed.
# Skip 'T0287.txt', already processed.
# Skip 'T0288.txt', already processed.
# Skip 'T0289.txt', already processed.
# Skip 'T0290.txt', already processed.
# Skip 'T0291.txt', already processed.
# Skip 'T0292.txt', already processed.
# Skip 'T0293.txt', already processed.
# Skip 'T0294.txt', already processed.
# Skip 'T0295.txt', already processed.
# Skip 'T0296.txt', already processed.
# Skip 'T0297.txt', already processed.
# Skip 'T0298.txt', already processed.
# Skip 'T0299.txt', already processed.
# Skip 'T0300.txt', already processed.
# Skip 'T0301.txt', already processed.
# Skip 'T0302.txt', already processed.
# Skip 'T0303.txt', already processed.
# Skip 'T0304.txt', already processed.
# Skip 'T0305.txt', already processed.
# Skip 'T0306.txt', already processed.
# Skip 'T0307.txt', already processed.
# Skip 'T0308.txt', already processed.
# Skip 'T0309.txt', already processed.
# Skip 'T0310.txt', already processed.
# Skip 'T0311.txt', already processed.
# Skip 'T0312.txt', already processed.
# Skip 'T0313.txt', already processed.
# Skip 'T0314.txt', already processed.
# Skip 'T0315.txt', already processed.
# Skip 'T0316.txt', already processed.
# Skip 'T0317.txt', already processed.
# Skip 'T0318.txt', already processed.
# Skip 'T0319.txt', already processed.
# Skip 'T0320.txt', already processed.
# Skip 'T0321.txt', already processed.
# Skip 'T0322.txt', already processed.
# Skip 'T0323.txt', already processed.
# Skip 'T0324.txt', already processed.
# Skip 'T0325.txt', already processed.
# Skip 'T0326.txt', already processed.
# Skip 'T0327.txt', already processed.
# Skip 'T0328.txt', already processed.
# Skip 'T0329.txt', already processed.
# Skip 'T0330.txt', already processed.
# Skip 'T0331.txt', already processed.
# Skip 'T0332.txt', already processed.
# Skip 'T0333.txt', already processed.
# Skip 'T0334.txt', already processed.
# Skip 'T0335.txt', already processed.
# Skip 'T0336.txt', already processed.
# Skip 'T0337.txt', already processed.
# Skip 'T0338.txt', already processed.
# Skip 'T0339.txt', already processed.
# Skip 'T0340.txt', already processed.
# Skip 'T0341.txt', already processed.
# Skip 'T0342.txt', already processed.
# Skip 'T0343.txt', already processed.
# Skip 'T0344.txt', already processed.
# Skip 'T0345.txt', already processed.
# Skip 'T0346.txt', already processed.
# Skip 'T0347.txt', already processed.
# Skip 'T0348.txt', already processed.
# Skip 'T0349.txt', already processed.
# Skip 'T0350.txt', already processed.
# Skip 'T0351.txt', already processed.
# Skip 'T0352.txt', already processed.
# Skip 'T0353.txt', already processed.
# Skip 'T0354.txt', already processed.
# Skip 'T0355.txt', already processed.
# Skip 'T0356.txt', already processed.
# Skip 'T0357.txt', already processed.
# Skip 'T0358.txt', already processed.
# Skip 'T0359.txt', already processed.
# Skip 'T0360.txt', already processed.
# Skip 'T0361.txt', already processed.
# Skip 'T0362.txt', already processed.
# Skip 'T0363.txt', already processed.
# Skip 'T0364.txt', already processed.
# Skip 'T0365.txt', already processed.
# Skip 'T0366.txt', already processed.
# Skip 'T0367.txt', already processed.
# Skip 'T0368.txt', already processed.
# Skip 'T0369.txt', already processed.
# Skip 'T0370.txt', already processed.
# Skip 'T0371.txt', already processed.
# Skip 'T0372.txt', already processed.
# Skip 'T0373.txt', already processed.
# Skip 'T0374.txt', already processed.
# Skip 'T0375.txt', already processed.
# Skip 'T0376.txt', already processed.
# Skip 'T0377.txt', already processed.
# Skip 'T0378.txt', already processed.
# Skip 'T0379.txt', already processed.
# Skip 'T0380.txt', already processed.
# Skip 'T0381.txt', already processed.
# Skip 'T0382.txt', already processed.
# Skip 'T0383.txt', already processed.
# Skip 'T0384.txt', already processed.
# Skip 'T0385.txt', already processed.
# Skip 'T0386.txt', already processed.
# Skip 'T0387.txt', already processed.
# Skip 'T0388.txt', already processed.
# Skip 'T0389.txt', already processed.
# Skip 'T0390.txt', already processed.
# Skip 'T0391.txt', already processed.
# Skip 'T0392.txt', already processed.
# Skip 'T0393.txt', already processed.
# Skip 'T0394.txt', already processed.
# Skip 'T0395.txt', already processed.
# Skip 'T0396.txt', already processed.
# Skip 'T0397.txt', already processed.
# Skip 'T0398.txt', already processed.
# Skip 'T0399.txt', already processed.
# Skip 'T0400.txt', already processed.
# Skip 'T0401.txt', already processed.
# Skip 'T0402.txt', already processed.
# Skip 'T0403.txt', already processed.
# Skip 'T0404.txt', already processed.
# Skip 'T0405.txt', already processed.
# Skip 'T0406.txt', already processed.
# Skip 'T0407.txt', already processed.
# Skip 'T0408.txt', already processed.
# Skip 'T0409.txt', already processed.
# Skip 'T0410.txt', already processed.
# Skip 'T0411.txt', already processed.
# Skip 'T0412.txt', already processed.
# Skip 'T0413.txt', already processed.
# Skip 'T0414.txt', already processed.
# Skip 'T0415.txt', already processed.
# Skip 'T0416.txt', already processed.
# Skip 'T0417.txt', already processed.
# Skip 'T0418.txt', already processed.
# Skip 'T0419.txt', already processed.
# Skip 'T0420.txt', already processed.
# Skip 'T0421.txt', already processed.
# Skip 'T0422.txt', already processed.
# Skip 'T0423.txt', already processed.
# Skip 'T0424.txt', already processed.
# Skip 'T0425.txt', already processed.
# Skip 'T0426.txt', already processed.
# Skip 'T0427.txt', already processed.
# Skip 'T0428.txt', already processed.
# Skip 'T0429.txt', already processed.
# Skip 'T0430.txt', already processed.
# Skip 'T0431.txt', already processed.
# Skip 'T0432.txt', already processed.
# Skip 'T0433.txt', already processed.
# Skip 'T0434.txt', already processed.
# Skip 'T0435.txt', already processed.
# Skip 'T0436.txt', already processed.
# Skip 'T0437.txt', already processed.
# Skip 'T0438.txt', already processed.
# Skip 'T0439.txt', already processed.
# Skip 'T0440.txt', already processed.
# Skip 'T0441.txt', already processed.
# Skip 'T0442.txt', already processed.
# Skip 'T0443.txt', already processed.
# Skip 'T0444.txt', already processed.
# Skip 'T0445.txt', already processed.
# Skip 'T0446.txt', already processed.
# Skip 'T0447.txt', already processed.
# Skip 'T0448.txt', already processed.
# Skip 'T0449.txt', already processed.
# Skip 'T0450.txt', already processed.
# Skip 'T0451.txt', already processed.
# Skip 'T0452.txt', already processed.
# Skip 'T0453.txt', already processed.
# Skip 'T0454.txt', already processed.
# Skip 'T0455.txt', already processed.
# Skip 'T0456.txt', already processed.
# Skip 'T0457.txt', already processed.
# Skip 'T0458.txt', already processed.
# Skip 'T0459.txt', already processed.
# Skip 'T0460.txt', already processed.
# Skip 'T0461.txt', already processed.
# Skip 'T0462.txt', already processed.
# Skip 'T0463.txt', already processed.
# Skip 'T0464.txt', already processed.
# Skip 'T0465.txt', already processed.
# Skip 'T0466.txt', already processed.
# Skip 'T0467.txt', already processed.
# Skip 'T0468.txt', already processed.
# Skip 'T0469.txt', already processed.
# Skip 'T0470.txt', already processed.
# Skip 'T0471.txt', already processed.
# Skip 'T0472.txt', already processed.
# Skip 'T0473.txt', already processed.
# Skip 'T0474.txt', already processed.
# Skip 'T0475.txt', already processed.
# Skip 'T0476.txt', already processed.
# Skip 'T0477.txt', already processed.
# Skip 'T0478.txt', already processed.
# Skip 'T0479.txt', already processed.
# Skip 'T0480.txt', already processed.
# Skip 'T0481.txt', already processed.
# Skip 'T0482.txt', already processed.
# Skip 'T0483.txt', already processed.
# Skip 'T0484.txt', already processed.
# Skip 'T0485.txt', already processed.
# Skip 'T0486.txt', already processed.
# Skip 'T0487.txt', already processed.
# Skip 'T0488.txt', already processed.
# Skip 'T0489.txt', already processed.
# Skip 'T0490.txt', already processed.
# Skip 'T0491.txt', already processed.
# Skip 'T0492.txt', already processed.
# Skip 'T0493.txt', already processed.
# Skip 'T0494.txt', already processed.
# Skip 'T0495.txt', already processed.
# Skip 'T0496.txt', already processed.
# Skip 'T0497.txt', already processed.
# Skip 'T0498.txt', already processed.
# Skip 'T0499.txt', already processed.
# Skip 'T0500.txt', already processed.
# Skip 'T0501.txt', already processed.
# Skip 'T0502.txt', already processed.
# Skip 'T0503.txt', already processed.
# Skip 'T0504.txt', already processed.
# Skip 'T0505.txt', already processed.
# Skip 'T0506.txt', already processed.
# Skip 'T0507.txt', already processed.
# Skip 'T0508.txt', already processed.
# Skip 'T0509.txt', already processed.
# Skip 'T0510.txt', already processed.
# Skip 'T0511.txt', already processed.
# Skip 'T0512.txt', already processed.
# Skip 'T0513.txt', already processed.
# Skip 'T0514.txt', already processed.
# Skip 'T0515.txt', already processed.
# Skip 'T0516.txt', already processed.
# Skip 'T0517.txt', already processed.
# Skip 'T0518.txt', already processed.
# Skip 'T0519.txt', already processed.
# Skip 'T0520.txt', already processed.
# Skip 'T0521.txt', already processed.
# Skip 'T0522.txt', already processed.
# Skip 'T0523.txt', already processed.
# Skip 'T0524.txt', already processed.
# Skip 'T0525.txt', already processed.
# Skip 'T0526.txt', already processed.
# Skip 'T0527.txt', already processed.
# Skip 'T0528.txt', already processed.
# Skip 'T0529.txt', already processed.
# Skip 'T0530.txt', already processed.
# Skip 'T0531.txt', already processed.
# Skip 'T0532.txt', already processed.
# Skip 'T0533.txt', already processed.
# Skip 'T0534.txt', already processed.
# Skip 'T0535.txt', already processed.
# Skip 'T0536.txt', already processed.
# Skip 'T0537.txt', already processed.
# Skip 'T0538.txt', already processed.
# Skip 'T0539.txt', already processed.
# Skip 'T0540.txt', already processed.
# Skip 'T0541.txt', already processed.
# Skip 'T0542.txt', already processed.
# Skip 'T0543.txt', already processed.
# Skip 'T0544.txt', already processed.
# Skip 'T0545.txt', already processed.
# Skip 'T0546.txt', already processed.
# Skip 'T0547.txt', already processed.
# Skip 'T0548.txt', already processed.
# Skip 'T0549.txt', already processed.
# Skip 'T0550.txt', already processed.
# Skip 'T0551.txt', already processed.
# Skip 'T0552.txt', already processed.
# Skip 'T0553.txt', already processed.
# Skip 'T0554.txt', already processed.
# Skip 'T0555.txt', already processed.
# Skip 'T0556.txt', already processed.
# Skip 'T0557.txt', already processed.
# Skip 'T0558.txt', already processed.
# Skip 'T0559.txt', already processed.
# Skip 'T0560.txt', already processed.
# Skip 'T0561.txt', already processed.
# Skip 'T0562.txt', already processed.
# Skip 'T0563.txt', already processed.
# Skip 'T0564.txt', already processed.
# Skip 'T0565.txt', already processed.
# Skip 'T0566.txt', already processed.
# Skip 'T0567.txt', already processed.
# Skip 'T0568.txt', already processed.
# Skip 'T0569.txt', already processed.
# Skip 'T0570.txt', already processed.
# Skip 'T0571.txt', already processed.
# Skip 'T0572.txt', already processed.
# Skip 'T0573.txt', already processed.
# Skip 'T0574.txt', already processed.
# Skip 'T0575.txt', already processed.
# Skip 'T0576.txt', already processed.
# Skip 'T0577.txt', already processed.
# Skip 'T0578.txt', already processed.
# Skip 'T0579.txt', already processed.
# Skip 'T0580.txt', already processed.
# Skip 'T0581.txt', already processed.
# Skip 'T0582.txt', already processed.
# Skip 'T0583.txt', already processed.
# Skip 'T0584.txt', already processed.
# Skip 'T0585.txt', already processed.
# Skip 'T0586.txt', already processed.
# Skip 'T0587.txt', already processed.
# Skip 'T0588.txt', already processed.
# Skip 'T0589.txt', already processed.
# Skip 'T0590.txt', already processed.
# Skip 'T0591.txt', already processed.
# Skip 'T0592.txt', already processed.
# Skip 'T0593.txt', already processed.
# Skip 'T0594.txt', already processed.
# Skip 'T0595.txt', already processed.
# Skip 'T0596.txt', already processed.
# Skip 'T0597.txt', already processed.
# Skip 'T0598.txt', already processed.
# Skip 'T0599.txt', already processed.
# Skip 'T0600.txt', already processed.
# Skip 'T0601.txt', already processed.
# Skip 'T0602.txt', already processed.
# Skip 'T0603.txt', already processed.
# Skip 'T0604.txt', already processed.
# Skip 'T0605.txt', already processed.
# Skip 'T0606.txt', already processed.
# Skip 'T0607.txt', already processed.
# Skip 'T0608.txt', already processed.
# Skip 'T0609.txt', already processed.
# Skip 'T0610.txt', already processed.
# Skip 'T0611.txt', already processed.
# Skip 'T0612.txt', already processed.
# Skip 'T0613.txt', already processed.
# Skip 'T0614.txt', already processed.
# Skip 'T0615.txt', already processed.
# Skip 'T0616.txt', already processed.
# Skip 'T0617.txt', already processed.
# Skip 'T0618.txt', already processed.
# Skip 'T0619.txt', already processed.
# Skip 'T0620.txt', already processed.
# Skip 'T0621.txt', already processed.
# Skip 'T0622.txt', already processed.
# Skip 'T0623.txt', already processed.
# Skip 'T0624.txt', already processed.
# Skip 'T0625.txt', already processed.
# Skip 'T0626.txt', already processed.
# Skip 'T0627.txt', already processed.
# Skip 'T0628.txt', already processed.
# Skip 'T0629.txt', already processed.
# Skip 'T0630.txt', already processed.
# Skip 'T0631.txt', already processed.
# Skip 'T0632.txt', already processed.
# Skip 'T0633.txt', already processed.
# Skip 'T0634.txt', already processed.
# Skip 'T0635.txt', already processed.
# Skip 'T0636.txt', already processed.
# Skip 'T0637.txt', already processed.
# Skip 'T0638.txt', already processed.
# Skip 'T0639.txt', already processed.
# Skip 'T0640.txt', already processed.
# Skip 'T0641.txt', already processed.
# Skip 'T0642.txt', already processed.
# Skip 'T0643.txt', already processed.
# Skip 'T0644.txt', already processed.
# Skip 'T0645.txt', already processed.
# Skip 'T0646.txt', already processed.
# Skip 'T0647.txt', already processed.
# Skip 'T0648.txt', already processed.
# Skip 'T0649.txt', already processed.
# Skip 'T0650.txt', already processed.
# Skip 'T0651.txt', already processed.
# Skip 'T0652.txt', already processed.
# Skip 'T0653.txt', already processed.
# Skip 'T0654.txt', already processed.
# Skip 'T0655.txt', already processed.
# Skip 'T0656.txt', already processed.
# Skip 'T0657.txt', already processed.
# Skip 'T0658.txt', already processed.
# Skip 'T0659.txt', already processed.
# Skip 'T0660.txt', already processed.
# Skip 'T0661.txt', already processed.
# Skip 'T0662.txt', already processed.
# Skip 'T0663.txt', already processed.
# Skip 'T0664.txt', already processed.
# Skip 'T0665.txt', already processed.
# Skip 'T0666.txt', already processed.
# Skip 'T0667.txt', already processed.
# Skip 'T0668.txt', already processed.
# Skip 'T0669.txt', already processed.
# Skip 'T0670.txt', already processed.
# Skip 'T0671.txt', already processed.
# Skip 'T0672.txt', already processed.
# Skip 'T0673.txt', already processed.
# Skip 'T0674.txt', already processed.
# Skip 'T0675.txt', already processed.
# Skip 'T0676.txt', already processed.
# Skip 'T0677.txt', already processed.
# Skip 'T0678.txt', already processed.
# Skip 'T0679.txt', already processed.
# Skip 'T0680.txt', already processed.
# Skip 'T0681.txt', already processed.
# Skip 'T0682.txt', already processed.
# Skip 'T0683.txt', already processed.
# Skip 'T0684.txt', already processed.
# Skip 'T0685.txt', already processed.
# Skip 'T0686.txt', already processed.
# Skip 'T0687.txt', already processed.
# Skip 'T0688.txt', already processed.
# Skip 'T0689.txt', already processed.
# Skip 'T0690.txt', already processed.
# Skip 'T0691.txt', already processed.
# Skip 'T0692.txt', already processed.
# Skip 'T0693.txt', already processed.
# Skip 'T0694.txt', already processed.
# Skip 'T0695.txt', already processed.
# Skip 'T0696.txt', already processed.
# Skip 'T0697.txt', already processed.
# Skip 'T0698.txt', already processed.
# Skip 'T0699.txt', already processed.
# Skip 'T0700.txt', already processed.
# Skip 'T0701.txt', already processed.
# Skip 'T0702.txt', already processed.
# Skip 'T0703.txt', already processed.
# Skip 'T0704.txt', already processed.
# Skip 'T0705.txt', already processed.
# Skip 'T0706.txt', already processed.
# Skip 'T0707.txt', already processed.
# Skip 'T0708.txt', already processed.
# Skip 'T0709.txt', already processed.
# Skip 'T0710.txt', already processed.
# Skip 'T0711.txt', already processed.
# Skip 'T0712.txt', already processed.
# Skip 'T0713.txt', already processed.
# Skip 'T0714.txt', already processed.
# Skip 'T0715.txt', already processed.
# Skip 'T0716.txt', already processed.
# Skip 'T0717.txt', already processed.
# Skip 'T0718.txt', already processed.
# Skip 'T0719.txt', already processed.
# Skip 'T0720.txt', already processed.
# Skip 'T0721.txt', already processed.
# Skip 'T0722.txt', already processed.
# Skip 'T0723.txt', already processed.
# Skip 'T0724.txt', already processed.
# Skip 'T0725.txt', already processed.
# Skip 'T0726.txt', already processed.
# Skip 'T0727.txt', already processed.
# Skip 'T0728.txt', already processed.
# Skip 'T0729.txt', already processed.
# Skip 'T0730.txt', already processed.
# Skip 'T0731.txt', already processed.
# Skip 'T0732.txt', already processed.
# Skip 'T0733.txt', already processed.
# Skip 'T0734.txt', already processed.
# Skip 'T0735.txt', already processed.
# Skip 'T0736.txt', already processed.
# Skip 'T0737.txt', already processed.
# Skip 'T0738.txt', already processed.
# Skip 'T0739.txt', already processed.
# Skip 'T0740.txt', already processed.
# Skip 'T0741.txt', already processed.
# Skip 'T0742.txt', already processed.
# Skip 'T0743.txt', already processed.
# Skip 'T0744.txt', already processed.
# Skip 'T0745.txt', already processed.
# Skip 'T0746.txt', already processed.
# Skip 'T0747.txt', already processed.
# Skip 'T0748.txt', already processed.
# Skip 'T0749.txt', already processed.
# Skip 'T0750.txt', already processed.
# Skip 'T0751.txt', already processed.
# Skip 'T0752.txt', already processed.
# Skip 'T0753.txt', already processed.
# Skip 'T0754.txt', already processed.
# Skip 'T0755.txt', already processed.
# Skip 'T0756.txt', already processed.
# Skip 'T0757.txt', already processed.
# Skip 'T0758.txt', already processed.
# Skip 'T0759.txt', already processed.
# Skip 'T0760.txt', already processed.
# Skip 'T0761.txt', already processed.
# Skip 'T0762.txt', already processed.
# Skip 'T0763.txt', already processed.
# Skip 'T0764.txt', already processed.
# Skip 'T0765.txt', already processed.
# Skip 'T0766.txt', already processed.
# Skip 'T0767.txt', already processed.
# Skip 'T0768.txt', already processed.
# Skip 'T0769.txt', already processed.
# Skip 'T0770.txt', already processed.
# Skip 'T0771.txt', already processed.
# Skip 'T0772.txt', already processed.
# Skip 'T0773.txt', already processed.
# Skip 'T0774.txt', already processed.
# Skip 'T0775.txt', already processed.
# Skip 'T0776.txt', already processed.
# Skip 'T0777.txt', already processed.
# Skip 'T0778.txt', already processed.
# Skip 'T0779.txt', already processed.
# Skip 'T0780.txt', already processed.
# Skip 'T0781.txt', already processed.
# Skip 'T0782.txt', already processed.
# Skip 'T0783.txt', already processed.
# Skip 'T0784.txt', already processed.
# Skip 'T0785.txt', already processed.
# Skip 'T0786.txt', already processed.
# Skip 'T0787.txt', already processed.
# Skip 'T0788.txt', already processed.
# Skip 'T0789.txt', already processed.
# Skip 'T0790.txt', already processed.
# Skip 'T0791.txt', already processed.
# Skip 'T0792.txt', already processed.
# Skip 'T0793.txt', already processed.
# Skip 'T0794.txt', already processed.
# Skip 'T0795.txt', already processed.
# Skip 'T0796.txt', already processed.
# Skip 'T0797.txt', already processed.
# Skip 'T0798.txt', already processed.
# Skip 'T0799.txt', already processed.
# Skip 'T0800.txt', already processed.
# Skip 'T0801.txt', already processed.
# Skip 'T0802.txt', already processed.
# Skip 'T0803.txt', already processed.
# Skip 'T0804.txt', already processed.
# Skip 'T0805.txt', already processed.
# Skip 'T0806.txt', already processed.
# Skip 'T0807.txt', already processed.
# Skip 'T0808.txt', already processed.
# Skip 'T0809.txt', already processed.
# Skip 'T0810.txt', already processed.
# Skip 'T0811.txt', already processed.
# Skip 'T0812.txt', already processed.
# Skip 'T0813.txt', already processed.
# Skip 'T0814.txt', already processed.
# Skip 'T0815.txt', already processed.
# Skip 'T0816.txt', already processed.
# Skip 'T0817.txt', already processed.
# Skip 'T0818.txt', already processed.
# Skip 'T0819.txt', already processed.
# Skip 'T0820.txt', already processed.
# Skip 'T0821.txt', already processed.
# Skip 'T0822.txt', already processed.
# Skip 'T0823.txt', already processed.
# Skip 'T0824.txt', already processed.
# Skip 'T0825.txt', already processed.
# Skip 'T0826.txt', already processed.
# Skip 'T0827.txt', already processed.
# Skip 'T0828.txt', already processed.
# Skip 'T0829.txt', already processed.
# Skip 'T0830.txt', already processed.
# Skip 'T0831.txt', already processed.
# Skip 'T0832.txt', already processed.
# Skip 'T0833.txt', already processed.
# Skip 'T0834.txt', already processed.
# Skip 'T0835.txt', already processed.
# Skip 'T0836.txt', already processed.
# Skip 'T0837.txt', already processed.
# Skip 'T0838.txt', already processed.
# Skip 'T0839.txt', already processed.
# Skip 'T0840.txt', already processed.
# Skip 'T0841.txt', already processed.
# Skip 'T0842.txt', already processed.
# Skip 'T0843.txt', already processed.
# Skip 'T0844.txt', already processed.
# Skip 'T0845.txt', already processed.
# Skip 'T0846.txt', already processed.
# Skip 'T0847.txt', already processed.
# Skip 'T0848.txt', already processed.
# Skip 'T0849.txt', already processed.
# Skip 'T0850.txt', already processed.
# Skip 'T0851.txt', already processed.
# Skip 'T0852.txt', already processed.
# Skip 'T0853.txt', already processed.
# Skip 'T0854.txt', already processed.
# Skip 'T0855.txt', already processed.
# Skip 'T0856.txt', already processed.
# Skip 'T0857.txt', already processed.
# Skip 'T0858.txt', already processed.
# Skip 'T0859.txt', already processed.
# Skip 'T0860.txt', already processed.
# Skip 'T0861.txt', already processed.
# Skip 'T0862.txt', already processed.
# Skip 'T0863.txt', already processed.
# Skip 'T0864.txt', already processed.
# Skip 'T0865.txt', already processed.
# Skip 'T0866.txt', already processed.
# Skip 'T0867.txt', already processed.
# Skip 'T0868.txt', already processed.
# Skip 'T0869.txt', already processed.
# Skip 'T0870.txt', already processed.
# Skip 'T0871.txt', already processed.
# Skip 'T0872.txt', already processed.
# Skip 'T0873.txt', already processed.
# Skip 'T0874.txt', already processed.
# Skip 'T0875.txt', already processed.
# Skip 'T0876.txt', already processed.
# Skip 'T0877.txt', already processed.
# Skip 'T0878.txt', already processed.
# Skip 'T0879.txt', already processed.
# Skip 'T0880.txt', already processed.
# Skip 'T0881.txt', already processed.
# Skip 'T0882.txt', already processed.
# Skip 'T0883.txt', already processed.
# Skip 'T0884.txt', already processed.
# Skip 'T0885.txt', already processed.
# Skip 'T0886.txt', already processed.
# Skip 'T0887.txt', already processed.
# Skip 'T0888.txt', already processed.
# Skip 'T0889.txt', already processed.
# Skip 'T0890.txt', already processed.
# Skip 'T0891.txt', already processed.
# Skip 'T0892.txt', already processed.
# Skip 'T0893.txt', already processed.
# Skip 'T0894.txt', already processed.
# Skip 'T0895.txt', already processed.
# Skip 'T0896.txt', already processed.
# Skip 'T0897.txt', already processed.
# Skip 'T0898.txt', already processed.
# Skip 'T0899.txt', already processed.
# Skip 'T0900.txt', already processed.
# Skip 'T0901.txt', already processed.
# Skip 'T0902.txt', already processed.
# Skip 'T0903.txt', already processed.
# Skip 'T0904.txt', already processed.
# Skip 'T0905.txt', already processed.
# Skip 'T0906.txt', already processed.
# Skip 'T0907.txt', already processed.
# Skip 'T0908.txt', already processed.
# Skip 'T0909.txt', already processed.
# Skip 'T0910.txt', already processed.
# Skip 'T0911.txt', already processed.
# Skip 'T0912.txt', already processed.
# Skip 'T0913.txt', already processed.
# Skip 'T0914.txt', already processed.
# Skip 'T0915.txt', already processed.
# Skip 'T0916.txt', already processed.
# Skip 'T0917.txt', already processed.
# Skip 'T0918.txt', already processed.
# Skip 'T0919.txt', already processed.
# Skip 'T0920.txt', already processed.
# Skip 'T0921.txt', already processed.
# Skip 'T0922.txt', already processed.
# Skip 'T0923.txt', already processed.
# Skip 'T0924.txt', already processed.
# Skip 'T0925.txt', already processed.
# Skip 'T0926.txt', already processed.
# Skip 'T0927.txt', already processed.
# Skip 'T0928.txt', already processed.
# Skip 'T0929.txt', already processed.
# Skip 'T0930.txt', already processed.
# Skip 'T0931.txt', already processed.
# Skip 'T0932.txt', already processed.
# Skip 'T0933.txt', already processed.
# Skip 'T0934.txt', already processed.
# Skip 'T0935.txt', already processed.
# Skip 'T0936.txt', already processed.
# Skip 'T0937.txt', already processed.
# Skip 'T0938.txt', already processed.
# Skip 'T0939.txt', already processed.
# Skip 'T0940.txt', already processed.
# Skip 'T0941.txt', already processed.
# Skip 'T0942.txt', already processed.
# Skip 'T0943.txt', already processed.
# Skip 'T0944.txt', already processed.
# Skip 'T0945.txt', already processed.
# Skip 'T0946.txt', already processed.
# Skip 'T0947.txt', already processed.
# Skip 'T0948.txt', already processed.
# Skip 'T0949.txt', already processed.
# Skip 'T0950.txt', already processed.
# Skip 'T0951.txt', already processed.
# Skip 'T0952.txt', already processed.
# Skip 'T0953.txt', already processed.
# Skip 'T0954.txt', already processed.
# Skip 'T0955.txt', already processed.
# Skip 'T0956.txt', already processed.
# Skip 'T0957.txt', already processed.
# Skip 'T0958.txt', already processed.
# Skip 'T0959.txt', already processed.
# Skip 'T0960.txt', already processed.
# Skip 'T0961.txt', already processed.
# Skip 'T0962.txt', already processed.
# Skip 'T0963.txt', already processed.
# Skip 'T0964.txt', already processed.
# Skip 'T0965.txt', already processed.
# Skip 'T0966.txt', already processed.
# Skip 'T0967.txt', already processed.
# Skip 'T0968.txt', already processed.
# Skip 'T0969.txt', already processed.
# Skip 'T0970.txt', already processed.
# Skip 'T0971.txt', already processed.
# Skip 'T0972.txt', already processed.
# Skip 'T0973.txt', already processed.
# Skip 'T0974.txt', already processed.
# Skip 'T0975.txt', already processed.
# Skip 'T0976.txt', already processed.
# Skip 'T0977.txt', already processed.
# Skip 'T0978.txt', already processed.
# Skip 'T0979.txt', already processed.
# Skip 'T0980.txt', already processed.
# Skip 'T0981.txt', already processed.
# Skip 'T0982.txt', already processed.
# Skip 'T0983.txt', already processed.
# Skip 'T0984.txt', already processed.
# Skip 'T0985.txt', already processed.
# Skip 'T0986.txt', already processed.
# Skip 'T0987.txt', already processed.
# Skip 'T0988.txt', already processed.
# Skip 'T0989.txt', already processed.
# Skip 'T0990.txt', already processed.
# Skip 'T0991.txt', already processed.
# Skip 'T0992.txt', already processed.
# Skip 'T0993.txt', already processed.
# Skip 'T0994.txt', already processed.
# Skip 'T0995.txt', already processed.
# Skip 'T0996.txt', already processed.
# Skip 'T0997.txt', already processed.
# Skip 'T0998.txt', already processed.
# Skip 'T0999.txt', already processed.
# Skip 'T1000.txt', already processed.
# Skip 'T1001.txt', already processed.
# Skip 'T1002.txt', already processed.
# Skip 'T1003.txt', already processed.
# Skip 'T1004.txt', already processed.
# Skip 'T1005.txt', already processed.
# Skip 'T1006.txt', already processed.
# Skip 'T1007.txt', already processed.
# Skip 'T1008.txt', already processed.
# Skip 'T1009.txt', already processed.
# Skip 'T1010.txt', already processed.
# Skip 'T1011.txt', already processed.
# Skip 'T1012.txt', already processed.
# Skip 'T1013.txt', already processed.
# Skip 'T1014.txt', already processed.
# Skip 'T1015.txt', already processed.
# Skip 'T1016.txt', already processed.
# Skip 'T1017.txt', already processed.
# Skip 'T1018.txt', already processed.
# Skip 'T1019.txt', already processed.
# Skip 'T1020.txt', already processed.
# Skip 'T1021.txt', already processed.
# Skip 'T1022.txt', already processed.
# Skip 'T1023.txt', already processed.
# Skip 'T1024.txt', already processed.
# Skip 'T1025.txt', already processed.
# Skip 'T1026.txt', already processed.
# Skip 'T1027.txt', already processed.
# Skip 'T1028.txt', already processed.
# Skip 'T1029.txt', already processed.
# Skip 'T1030.txt', already processed.
# Skip 'T1031.txt', already processed.
# Skip 'T1032.txt', already processed.
# Skip 'T1033.txt', already processed.
# Skip 'T1034.txt', already processed.
# Skip 'T1035.txt', already processed.
# Skip 'T1036.txt', already processed.
# Skip 'T1037.txt', already processed.
# Skip 'T1038.txt', already processed.
# Skip 'T1039.txt', already processed.
# Skip 'T1040.txt', already processed.
# Skip 'T1041.txt', already processed.
# Skip 'T1042.txt', already processed.
# Skip 'T1043.txt', already processed.
# Skip 'T1044.txt', already processed.
# Skip 'T1045.txt', already processed.
# Skip 'T1046.txt', already processed.
# Skip 'T1047.txt', already processed.
# Skip 'T1048.txt', already processed.
# Skip 'T1049.txt', already processed.
# Skip 'T1050.txt', already processed.
# Skip 'T1051.txt', already processed.
# Skip 'T1052.txt', already processed.
# Skip 'T1053.txt', already processed.
# Skip 'T1054.txt', already processed.
# Skip 'T1055.txt', already processed.
# Skip 'T1056.txt', already processed.
# Skip 'T1057.txt', already processed.
# Skip 'T1058.txt', already processed.
# Skip 'T1059.txt', already processed.
# Skip 'T1060.txt', already processed.
# Skip 'T1061.txt', already processed.
# Skip 'T1062.txt', already processed.
# Skip 'T1063.txt', already processed.
# Skip 'T1064.txt', already processed.
# Skip 'T1065.txt', already processed.
# Skip 'T1066.txt', already processed.
# Skip 'T1067.txt', already processed.
# Skip 'T1068.txt', already processed.
# Skip 'T1069.txt', already processed.
# Skip 'T1070.txt', already processed.
# Skip 'T1071.txt', already processed.
# Skip 'T1072.txt', already processed.
# Skip 'T1073.txt', already processed.
# Skip 'T1074.txt', already processed.
# Skip 'T1075.txt', already processed.
# Skip 'T1076.txt', already processed.
# Skip 'T1077.txt', already processed.
# Skip 'T1078.txt', already processed.
# Skip 'T1079.txt', already processed.
# Skip 'T1080.txt', already processed.
# Skip 'T1081.txt', already processed.
# Skip 'T1082.txt', already processed.
# Skip 'T1083.txt', already processed.
# Skip 'T1084.txt', already processed.
# Skip 'T1085.txt', already processed.
# Skip 'T1086.txt', already processed.
# Skip 'T1087.txt', already processed.
# Skip 'T1088.txt', already processed.
# Skip 'T1089.txt', already processed.
# Skip 'T1090.txt', already processed.
# Skip 'T1091.txt', already processed.
# Skip 'T1092.txt', already processed.
# Skip 'T1093.txt', already processed.
# Skip 'T1094.txt', already processed.
# Skip 'T1095.txt', already processed.
# Skip 'T1096.txt', already processed.
# Skip 'T1097.txt', already processed.
# Skip 'T1098.txt', already processed.
# Skip 'T1099.txt', already processed.
# Skip 'T1100.txt', already processed.
# Skip 'T1101.txt', already processed.
# Skip 'T1102.txt', already processed.
# Skip 'T1103.txt', already processed.
# Skip 'T1104.txt', already processed.
# Skip 'T1105.txt', already processed.
# Skip 'T1106.txt', already processed.
# Skip 'T1107.txt', already processed.
# Skip 'T1108.txt', already processed.
# Skip 'T1109.txt', already processed.
# Skip 'T1110.txt', already processed.
# Skip 'T1111.txt', already processed.
# Skip 'T1112.txt', already processed.
# Skip 'T1113.txt', already processed.
# Skip 'T1114.txt', already processed.
# Skip 'T1115.txt', already processed.
# Skip 'T1116.txt', already processed.
# Skip 'T1117.txt', already processed.
# Skip 'T1118.txt', already processed.
# Skip 'T1119.txt', already processed.
# Skip 'T1120.txt', already processed.
# Skip 'T1121.txt', already processed.
# Skip 'T1122.txt', already processed.
# Skip 'T1123.txt', already processed.
# Skip 'T1124.txt', already processed.
# Skip 'T1125.txt', already processed.
# Skip 'T1126.txt', already processed.
# Skip 'T1127.txt', already processed.
# Skip 'T1128.txt', already processed.
# Skip 'T1129.txt', already processed.
# Skip 'T1130.txt', already processed.
# Skip 'T1131.txt', already processed.
# Skip 'T1132.txt', already processed.
# Skip 'T1133.txt', already processed.
# Skip 'T1134.txt', already processed.
# Skip 'T1135.txt', already processed.
# Skip 'T1136.txt', already processed.
# Skip 'T1137.txt', already processed.
# Skip 'T1138.txt', already processed.
# Skip 'T1139.txt', already processed.
# Skip 'T1140.txt', already processed.
# Skip 'T1141.txt', already processed.
# Skip 'T1142.txt', already processed.
# Skip 'T1143.txt', already processed.
# Skip 'T1144.txt', already processed.
# Skip 'T1145.txt', already processed.
# Skip 'T1146.txt', already processed.
# Skip 'T1147.txt', already processed.
# Skip 'T1148.txt', already processed.
# Skip 'T1149.txt', already processed.
# Skip 'T1150.txt', already processed.
# Skip 'T1151.txt', already processed.
# Skip 'T1152.txt', already processed.
# Skip 'T1153.txt', already processed.
# Skip 'T1154.txt', already processed.
# Skip 'T1155.txt', already processed.
# Skip 'T1156.txt', already processed.
# Skip 'T1157.txt', already processed.
# Skip 'T1158.txt', already processed.
# Skip 'T1159.txt', already processed.
# Skip 'T1160.txt', already processed.
# Skip 'T1161.txt', already processed.
# Skip 'T1162.txt', already processed.
# Skip 'T1163.txt', already processed.
# Skip 'T1164.txt', already processed.
# Skip 'T1165.txt', already processed.
# Skip 'T1166.txt', already processed.
# Skip 'T1167.txt', already processed.
# Skip 'T1168.txt', already processed.
# Skip 'T1169.txt', already processed.
# Processing 'T1170.txt'...
# [Success] Extracted 16 paraphrases.
# Saved paraphrases for 'T1170.txt'.
# Skip 'T1171.txt', already processed.
# Skip 'T1172.txt', already processed.
# Skip 'T1173.txt', already processed.
# Skip 'T1174.txt', already processed.
# Skip 'T1175.txt', already processed.
# Skip 'T1176.txt', already processed.
# Skip 'T1177.txt', already processed.
# Skip 'T1178.txt', already processed.
# Skip 'T1179.txt', already processed.
# Skip 'T1180.txt', already processed.
# Skip 'T1181.txt', already processed.
# Skip 'T1182.txt', already processed.
# Skip 'T1183.txt', already processed.
# Skip 'T1184.txt', already processed.
# Skip 'T1185.txt', already processed.
# Skip 'T1186.txt', already processed.
# Skip 'T1187.txt', already processed.
# Skip 'T1188.txt', already processed.
# Skip 'T1189.txt', already processed.
# Skip 'T1190.txt', already processed.
# Skip 'T1191.txt', already processed.
# Skip 'T1192.txt', already processed.
# Skip 'T1193.txt', already processed.
# Skip 'T1194.txt', already processed.
# Skip 'T1195.txt', already processed.
# Skip 'T1196.txt', already processed.
# Skip 'T1197.txt', already processed.
# Skip 'T1198.txt', already processed.
# Skip 'T1199.txt', already processed.
# Skip 'T1200.txt', already processed.
