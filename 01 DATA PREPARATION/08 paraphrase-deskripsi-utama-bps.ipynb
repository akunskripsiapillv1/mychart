# %%
from google.colab import drive
import os
import pandas as pd
from openai import OpenAI
import time
import json
import re

# %%
# 1. Mount Google Drive
drive.mount('/content/drive', force_remount=True)

# 2. Path file metadata dan folder CSV serta output
base_folder = "/content/drive/My Drive/AYOK BIKIN DATASET"
csv_folder = os.path.join(base_folder, "[01] TABLE")
metadata_file = os.path.join(base_folder, "[00] METADATA/Metadata Tabel.xlsx")
output_folder = os.path.join(base_folder, "[03] DESCRIPTION")
os.makedirs(output_folder, exist_ok=True)  # Pastikan folder output ada

# Folder input dan output
folder_deskripsi = "/content/drive/My Drive/AYOK BIKIN DATASET/[03] DESCRIPTION"
folder_hasil = "/content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]"
os.makedirs(folder_hasil, exist_ok=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# GPT 4o-mini

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.59.9)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)

# %%
# Set your OpenAI API key as an environment variable named OPENAI_API_KEY
# Replace 'YOUR_ACTUAL_API_KEY' with your actual API key
os.environ['OPENAI_API_KEY'] = 'OPENAI_API_KEY'

# Now you can access it using os.environ['OPENAI_API_KEY']
client = OpenAI(
  api_key=os.environ['OPENAI_API_KEY'],  # Accessing the environment variable
)

# %%
import os
print(os.environ.get('OPENAI_API_KEY'))

# %%
def generate_parafrase(teks, batch_ke):
    """
    Fungsi untuk meminta 10 parafrase per batch.
    Jika batch kedua, berikan instruksi agar tidak mengulang batch pertama tanpa mencantumkan daftar sebelumnya.
    """
    tambahan_instruksi = ""

    if batch_ke == 2:
        tambahan_instruksi = (
            "\n\nPerhatian: Jangan mengulang struktur atau pola kalimat dari parafrase yang telah dihasilkan sebelumnya. "
        )

    prompt = (
        f"Saya ingin anda melakukan parafrase tepat 10 kali terhadap teks yang saya input, tidak lebih dan tidak kurang. "
        "Tujuannya adalah menghasilkan narasi deskriptif dengan variasi linguistik melalui sinonim dan/atau perubahan struktur kalimat. "
        "Saya ingin anda berperan sebagai asisten pemrograman saya untuk otomatisasi parafrase sehingga saya tidak perlu membuat program sendiri. "
        "Penamaan variabel harus sama dengan teks asli. "
        "Khusus untuk kalimat akhir yang sebagai data keseluruhan, jangan tambahkan kata 'total' lagi karena telah diwakilkan oleh wilayahnya. "
        "Gunakan Bahasa Indonesia yang formal, efektif, dan kalimat sesuai EYD. "
        "Jangan menambahkan atau mencampur informasi baru kecuali saya memintanya. "
        f"Teks asli:\n{teks}\n\n"
        f"Kembalikan output dalam format JSON array, seperti ini:\n\n"
        "[\"Parafrase 1\", \"Parafrase 2\", ..., \"Parafrase 10\"]"
        f"{tambahan_instruksi}"  # **Tambahkan instruksi tambahan hanya untuk batch kedua**
    )

    # Panggil API OpenAI
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "Anda adalah asisten AI yang membantu parafrase teks."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.8,  # Meningkatkan kreativitas agar lebih bervariasi
    )

    # Ambil output mentah dari OpenAI
    response_text = response.choices[0].message.content.strip()
    print(f"Raw Response (Batch {batch_ke}):", response_text)  # Debugging untuk memastikan JSON valid

    # **Membersihkan format JSON dari karakter yang tidak diperlukan**
    clean_text = re.sub(r'```json|```', '', response_text).strip()  # Hilangkan backticks jika ada

    # Parsing JSON dengan validasi
    try:
        parafrase_list = json.loads(clean_text)

        # Pastikan jumlah sesuai dengan yang diminta
        if not isinstance(parafrase_list, list) or len(parafrase_list) != 10:
            raise ValueError(f"Model tidak mengembalikan tepat 10 elemen di batch {batch_ke}.")

    except (json.JSONDecodeError, ValueError) as e:
        print(f"❌ Gagal membaca JSON dari hasil model di batch {batch_ke}:", e)
        parafrase_list = []

    return parafrase_list  # Mengembalikan daftar hasil parafrase jika valid

# %%
def buat_parafrase(teks):
    """
    Fungsi ini menjalankan prompt dua kali:
    - Pertama untuk menghasilkan 10 parafrase.
    - Kedua untuk menghasilkan 10 parafrase lainnya yang berbeda dari batch pertama.
    Total output yang dihasilkan adalah 20 parafrase.
    """

    # **Menjalankan prompt pertama untuk 10 parafrase pertama**
    hasil_pertama = generate_parafrase(teks, batch_ke=1)

    # **Menjalankan prompt kedua untuk 10 parafrase berikutnya, menghindari duplikasi**
    hasil_kedua = generate_parafrase(teks, batch_ke=2)

    # **Gabungkan hasil pertama dan kedua**
    final_parafrase = hasil_pertama + hasil_kedua

    return final_parafrase  # Mengembalikan total 20 parafrase

# %%
# File untuk mencatat batch yang selesai
processed_batches_file = "/content/drive/My Drive/AYOK BIKIN DATASET/processed_batches.txt"

# Ambil semua file deskripsi
file_deskripsi_list = sorted([f for f in os.listdir(folder_deskripsi) if f.endswith(".txt")])

# **Tentukan ukuran batch**
batch_size = 10  # Setiap batch memproses 10 file

# **Cek batch terakhir yang sudah selesai**
try:
    with open(processed_batches_file, "r") as f:
        processed_batches = set(int(line.strip()) for line in f.readlines())  # Batch yang sudah selesai
except FileNotFoundError:
    processed_batches = set()

# Fungsi untuk memeriksa kelengkapan file
def cek_kelengkapan_file(file_id):
    base_filename = f"D{str(file_id).zfill(4)}"  # Format file output
    parafrase_files = [f for f in os.listdir(folder_hasil) if f.startswith(base_filename)]
    return len(parafrase_files) == 20  # Return True jika file lengkap

# Loop untuk setiap batch
for i in range(0, len(file_deskripsi_list), batch_size):
    batch_number = i // batch_size + 1  # Nomor batch

    # **Lewati batch yang sudah selesai**
    if batch_number in processed_batches:
        print(f"⏩ Melewati Batch {batch_number}, sudah diproses sebelumnya.")
        continue

    batch_files = file_deskripsi_list[i:i + batch_size]  # Ambil 10 file dalam batch ini
    print(f"🚀 Memproses Batch {batch_number}: {len(batch_files)} file...")

    for file_deskripsi in batch_files:
        file_id = int(file_deskripsi.replace("T", "").replace(".txt", ""))  # Ambil ID file
        path_deskripsi = os.path.join(folder_deskripsi, file_deskripsi)

        # **Cek apakah file sudah lengkap**
        if cek_kelengkapan_file(file_id):
            print(f"✔️ File {file_deskripsi} sudah lengkap. Lewati.")
            continue

        # Jika file belum lengkap, baca teks asli
        with open(path_deskripsi, "r", encoding="utf-8") as f:
            deskripsi_asli = f.read().strip()

        # Generate parafrase (20 kali)
        parafrase_hasil = buat_parafrase(deskripsi_asli)

        # Pastikan hasil valid sebelum menyimpan
        if len(parafrase_hasil) < 20:
            print(f"⚠️ Hanya {len(parafrase_hasil)} parafrase yang dihasilkan untuk {file_deskripsi}. Lewati penyimpanan.")
            continue

        # Simpan setiap parafrase dalam file txt terpisah
        base_filename = file_deskripsi.replace("T", "D").replace(".txt", "")

        for idx, teks_parafrase in enumerate(parafrase_hasil, start=1):
            nama_file_hasil = f"{base_filename}_{idx}.txt"
            path_hasil = os.path.join(folder_hasil, nama_file_hasil)

            with open(path_hasil, "w", encoding="utf-8") as f_hasil:
                f_hasil.write(teks_parafrase)

            print(f"✅ Menyimpan file: {path_hasil}")

    # **Catat batch yang sudah selesai agar tidak diulang**
    with open(processed_batches_file, "a") as f:
        f.write(f"{batch_number}\n")

    print(f"✔️ Batch {batch_number} selesai. Menunggu 5 detik sebelum batch berikutnya...")
    time.sleep(5)  # Tambahkan delay untuk menghindari rate limit API
# Out:
# ⏩ Melewati Batch 1, sudah diproses sebelumnya.
# ⏩ Melewati Batch 2, sudah diproses sebelumnya.
# ⏩ Melewati Batch 3, sudah diproses sebelumnya.
# ⏩ Melewati Batch 4, sudah diproses sebelumnya.
# 🚀 Memproses Batch 5: 10 file...
# ✔️ File T0891.txt sudah lengkap. Lewati.
# ✔️ File T0892.txt sudah lengkap. Lewati.
# ✔️ File T0893.txt sudah lengkap. Lewati.
# ✔️ File T0894.txt sudah lengkap. Lewati.
# ✔️ File T0895.txt sudah lengkap. Lewati.
# ✔️ File T0896.txt sudah lengkap. Lewati.
# ✔️ File T0897.txt sudah lengkap. Lewati.
# Raw Response (Batch 1): ```json
# [
#     "Pada tahun 2015, jumlah siswa Madrasah Aliyah (MA) di Kecamatan Kedungkandang tercatat sebanyak 366 orang, di Kecamatan Sukun sebanyak 318 orang, di Kecamatan Klojen sebanyak 957 orang, di Kecamatan Blimbing sebanyak 23 orang, dan di Kecamatan Lowokwaru mencapai 1.226 orang. Dengan demikian, jumlah siswa Madrasah Aliyah (MA) di Kota Malang berjumlah 2.890 orang.",
#
#     "Di tahun 2015, jumlah peserta didik Madrasah Aliyah (MA) di Kecamatan Kedungkandang adalah 366 orang, di Kecamatan Sukun sebanyak 318 orang, di Kecamatan Klojen sebanyak 957 orang, di Kecamatan Blimbing sejumlah 23 orang, dan di Kecamatan Lowokwaru sebanyak 1.226 orang. Maka dari itu, jumlah peserta didik Madrasah Aliyah (MA) di Kota Malang adalah 2.890 orang.",
#
#     "Pada tahun 2015, terdapat 366 siswa Madrasah Aliyah (MA) di Kecamatan Kedungkandang, 318 siswa di Kecamatan Sukun, 957 siswa di Kecamatan Klojen, 23 siswa di Kecamatan Blimbing, dan 1.226 siswa di Kecamatan Lowokwaru. Oleh karena itu, total siswa Madrasah Aliyah (MA) di Kota Malang adalah 2.890 orang.",
#     "Pada tahun 2015, tercatat jumlah peserta didik di Madrasah Aliyah (MA) Kecamatan Kedungkandang sebanyak 366 orang, di Kecamatan Sukun sebanyak 318 orang, di Kecamatan Klojen sebanyak 957 orang, di Kecamatan Blimbing berjumlah 23 orang, dan di Kecamatan Lowokwaru sebanyak 1.226 orang. Maka, total peserta didik Madrasah Aliyah (MA) di Kota Malang adalah 2.890 orang.",
#
#     "Tahun 2015 menyaksikan jumlah siswa Madrasah Aliyah (MA) di Kecamatan Kedungkandang sebanyak 366 orang, di Kecamatan Sukun 318 orang, di Kecamatan Klojen 957 orang, di Kecamatan Blimbing 23 orang, dan di Kecamatan Lowokwaru berjumlah 1.226 orang. Dengan demikian, jumlah keseluruhan siswa Madrasah Aliyah (MA) di Kota Malang mencapai 2.890 orang."
# ]
# ```
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_1.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_2.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_3.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_4.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_5.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_6.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_7.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_8.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_9.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_10.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_11.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_12.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_13.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_14.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_15.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_16.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_17.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_18.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_19.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0898_20.txt
# ✔️ File T0899.txt sudah lengkap. Lewati.
# ✔️ File T0900.txt sudah lengkap. Lewati.
# ✔️ Batch 5 selesai. Menunggu 5 detik sebelum batch berikutnya...
# ⏩ Melewati Batch 6, sudah diproses sebelumnya.
# ⏩ Melewati Batch 7, sudah diproses sebelumnya.
# ⏩ Melewati Batch 8, sudah diproses sebelumnya.
# ⏩ Melewati Batch 9, sudah diproses sebelumnya.
# ⏩ Melewati Batch 10, sudah diproses sebelumnya.
# ⏩ Melewati Batch 11, sudah diproses sebelumnya.
# ⏩ Melewati Batch 12, sudah diproses sebelumnya.
# ⏩ Melewati Batch 13, sudah diproses sebelumnya.
# ⏩ Melewati Batch 14, sudah diproses sebelumnya.
# ⏩ Melewati Batch 15, sudah diproses sebelumnya.
# ⏩ Melewati Batch 16, sudah diproses sebelumnya.
# ⏩ Melewati Batch 17, sudah diproses sebelumnya.
# ⏩ Melewati Batch 18, sudah diproses sebelumnya.
# ⏩ Melewati Batch 19, sudah diproses sebelumnya.
# ⏩ Melewati Batch 20, sudah diproses sebelumnya.
# ⏩ Melewati Batch 21, sudah diproses sebelumnya.
# ⏩ Melewati Batch 22, sudah diproses sebelumnya.
# ⏩ Melewati Batch 23, sudah diproses sebelumnya.
# ⏩ Melewati Batch 24, sudah diproses sebelumnya.
# ⏩ Melewati Batch 25, sudah diproses sebelumnya.
# 🚀 Memproses Batch 26: 10 file...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-edeeb339897e> in <cell line: 0>()
#      47
#      48         # Generate parafrase (20 kali)
# ---> 49         parafrase_hasil = buat_parafrase(deskripsi_asli)
#      50
#      51         # Pastikan hasil valid sebelum menyimpan
#
# <ipython-input-15-4d37d8c5a1c2> in buat_parafrase(teks)
#       8
#       9     # **Menjalankan prompt pertama untuk 10 parafrase pertama**
# ---> 10     hasil_pertama = generate_parafrase(teks, batch_ke=1)
#      11
#      12     # **Menjalankan prompt kedua untuk 10 parafrase berikutnya, menghindari duplikasi**
#
# <ipython-input-14-468b5951e8f6> in generate_parafrase(teks, batch_ke)
#      26
#      27     # Panggil API OpenAI
# ---> 28     response = client.chat.completions.create(
#      29         model="gpt-4o-mini",
#      30         messages=[
#
# /usr/local/lib/python3.11/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     277                         msg = f"Missing required argument: {quote(missing[0])}"
#     278                 raise TypeError(msg)
# --> 279             return func(*args, **kwargs)
#     280
#     281         return wrapper  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/openai/resources/chat/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     857     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     858         validate_response_format(response_format)
# --> 859         return self._post(
#     860             "/chat/completions",
#     861             body=maybe_transform(
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1281             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282         )
# -> 1283         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1284
#    1285     def patch(
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     958             retries_taken = 0
#     959
# --> 960         return self._request(
#     961             cast_to=cast_to,
#     962             options=options,
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in _request(self, cast_to, options, retries_taken, stream, stream_cls)
#     994
#     995         try:
# --> 996             response = self._client.send(
#     997                 request,
#     998                 stream=stream or self._should_stream_response_body(request=request),
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     912         auth = self._build_request_auth(request, auth)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#     916             auth=auth,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     940
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#     944                     follow_redirects=follow_redirects,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     977                 hook(request)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#     981                 for hook in self._event_hooks["response"]:
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1012
#    1013         with request_context(request=request):
# -> 1014             response = transport.handle_request(request)
#    1015
#    1016         assert isinstance(response.stream, SyncByteStream)
#
# /usr/local/lib/python3.11/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     248         )
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#     252         assert isinstance(resp.stream, typing.Iterable)
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     254
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#     258         # Return the response. Note that in this case we still have to manage
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     234                 try:
#     235                     # Send the request on the assigned connection.
# --> 236                     response = connection.handle_request(
#     237                         pool_request.request
#     238                     )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#     101             raise exc
#     102
# --> 103         return self._connection.handle_request(request)
#     104
#     105     def _connect(self, request: Request) -> NetworkStream:
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     134                 with Trace("response_closed", logger, request) as trace:
#     135                     self._response_closed()
# --> 136             raise exc
#     137
#     138     # Sending the request...
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     104                     headers,
#     105                     trailing_data,
# --> 106                 ) = self._receive_response_headers(**kwargs)
#     107                 trace.return_value = (
#     108                     http_version,
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     175
#     176         while True:
# --> 177             event = self._receive_event(timeout=timeout)
#     178             if isinstance(event, h11.Response):
#     179                 break
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     215
#     216             if event is h11.NEED_DATA:
# --> 217                 data = self._network_stream.read(
#     218                     self.READ_NUM_BYTES, timeout=timeout
#     219                 )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_backends/sync.py in read(self, max_bytes, timeout)
#     126         with map_exceptions(exc_map):
#     127             self._sock.settimeout(timeout)
# --> 128             return self._sock.recv(max_bytes)
#     129
#     130     def write(self, buffer: bytes, timeout: float | None = None) -> None:
#
# /usr/lib/python3.11/ssl.py in recv(self, buflen, flags)
#    1293                     "non-zero flags not allowed in calls to recv() on %s" %
#    1294                     self.__class__)
# -> 1295             return self.read(buflen)
#    1296         else:
#    1297             return super().recv(buflen, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1166                 return self._sslobj.read(len, buffer)
#    1167             else:
# -> 1168                 return self._sslobj.read(len)
#    1169         except SSLError as x:
#    1170             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
def generate_parafrase(teks, batch_ke):
    """
    Fungsi untuk meminta parafrase dalam batch:
    - Batch pertama: 5 parafrase
    - Batch kedua: 5 parafrase
    - Batch ketiga: 5 parafrase
    - Batch keempat: 5 parafrase

    Instruksi tambahan diberikan untuk batch kedua, ketiga, dan keempat agar tidak mengulang hasil sebelumnya.
    """
    tambahan_instruksi = ""

    if batch_ke > 1:
        tambahan_instruksi = (
            "\n\nPerhatian: Jangan mengulang struktur atau pola kalimat dari parafrase yang telah dihasilkan sebelumnya. "
        )

    jumlah_parafrase = 5

    prompt = (
        f"Saya ingin anda melakukan parafrase tepat {jumlah_parafrase} kali terhadap teks yang saya input, tidak lebih dan tidak kurang. "
        "Tujuannya adalah menghasilkan narasi deskriptif dengan variasi linguistik melalui sinonim dan/atau perubahan struktur kalimat. "
        "Saya ingin anda berperan sebagai asisten pemrograman saya untuk otomatisasi parafrase sehingga saya tidak perlu membuat program sendiri. "
        "Penamaan variabel harus sama dengan teks asli. "
        "Khusus untuk kalimat akhir yang sebagai data keseluruhan, jangan tambahkan kata 'total' lagi karena telah diwakilkan oleh wilayahnya. "
        "Gunakan Bahasa Indonesia yang formal, efektif, dan kalimat sesuai EYD. "
        "Jangan menambahkan atau mencampur informasi baru kecuali saya memintanya. "
        f"Teks asli:\n{teks}\n\n"
        f"Kembalikan output dalam format JSON array, seperti ini:\n\n"
        "[\"Parafrase 1\", \"Parafrase 2\", ..., \"Parafrase N\"]"
        f"{tambahan_instruksi}"
    )

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "Anda adalah asisten AI yang membantu parafrase teks."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.8,
    )

    response_text = response.choices[0].message.content.strip()
    print(f"Raw Response (Batch {batch_ke}):", response_text)  # Debugging

    clean_text = re.sub(r'```json|```', '', response_text).strip()

    try:
        parafrase_list = json.loads(clean_text)

        if not isinstance(parafrase_list, list) or len(parafrase_list) != jumlah_parafrase:
            raise ValueError(f"Model tidak mengembalikan tepat {jumlah_parafrase} elemen di batch {batch_ke}.")
    except (json.JSONDecodeError, ValueError) as e:
        print(f"❌ Gagal membaca JSON dari hasil model di batch {batch_ke}:", e)
        parafrase_list = []

    return parafrase_list

# %%
def buat_parafrase(teks):
    """
    Fungsi ini menjalankan prompt empat kali:
    - Batch 1 menghasilkan 5 parafrase.
    - Batch 2 menghasilkan 5 parafrase.
    - Batch 3 menghasilkan 5 parafrase.
    - Batch 4 menghasilkan 5 parafrase.
    Total output yang dihasilkan adalah 20 parafrase.
    """
    hasil_pertama = generate_parafrase(teks, batch_ke=1)
    hasil_kedua = generate_parafrase(teks, batch_ke=2)
    hasil_ketiga = generate_parafrase(teks, batch_ke=3)
    hasil_keempat = generate_parafrase(teks, batch_ke=4)

    final_parafrase = hasil_pertama + hasil_kedua + hasil_ketiga + hasil_keempat
    return final_parafrase

# %%
# File untuk mencatat batch yang selesai
processed_batches_file = "/content/drive/My Drive/AYOK BIKIN DATASET/processed_batches.txt"

# Ambil semua file deskripsi
file_deskripsi_list = sorted([f for f in os.listdir(folder_deskripsi) if f.endswith(".txt")])

batch_size = 10  # Setiap batch memproses 10 file

try:
    with open(processed_batches_file, "r") as f:
        processed_batches = set(int(line.strip()) for line in f.readlines())
except FileNotFoundError:
    processed_batches = set()

def cek_kelengkapan_file(file_id):
    base_filename = f"D{str(file_id).zfill(4)}"
    parafrase_files = [f for f in os.listdir(folder_hasil) if f.startswith(base_filename)]
    return len(parafrase_files) == 20

for i in range(0, len(file_deskripsi_list), batch_size):
    batch_number = i // batch_size + 1

    if batch_number in processed_batches:
        print(f"⏩ Melewati Batch {batch_number}, sudah diproses sebelumnya.")
        continue

    batch_files = file_deskripsi_list[i:i + batch_size]
    print(f"🚀 Memproses Batch {batch_number}: {len(batch_files)} file...")

    for file_deskripsi in batch_files:
        file_id = int(file_deskripsi.replace("T", "").replace(".txt", ""))
        path_deskripsi = os.path.join(folder_deskripsi, file_deskripsi)

        if cek_kelengkapan_file(file_id):
            print(f"✔️ File {file_deskripsi} sudah lengkap. Lewati.")
            continue

        with open(path_deskripsi, "r", encoding="utf-8") as f:
            deskripsi_asli = f.read().strip()

        parafrase_hasil = buat_parafrase(deskripsi_asli)

        if len(parafrase_hasil) < 20:
            print(f"⚠️ Hanya {len(parafrase_hasil)} parafrase yang dihasilkan untuk {file_deskripsi}. Lewati penyimpanan.")
            continue

        base_filename = file_deskripsi.replace("T", "D").replace(".txt", "")

        for idx, teks_parafrase in enumerate(parafrase_hasil, start=1):
            nama_file_hasil = f"{base_filename}_{idx}.txt"
            path_hasil = os.path.join(folder_hasil, nama_file_hasil)

            with open(path_hasil, "w", encoding="utf-8") as f_hasil:
                f_hasil.write(teks_parafrase)

            print(f"✅ Menyimpan file: {path_hasil}")

    with open(processed_batches_file, "a") as f:
        f.write(f"{batch_number}\n")

    print(f"✔️ Batch {batch_number} selesai. Menunggu 5 detik sebelum batch berikutnya...")
    time.sleep(5)
# Out:
# ⏩ Melewati Batch 1, sudah diproses sebelumnya.
# 🚀 Memproses Batch 2: 10 file...
# ✔️ File T0861.txt sudah lengkap. Lewati.
# ✔️ File T0862.txt sudah lengkap. Lewati.
# ✔️ File T0863.txt sudah lengkap. Lewati.
# ✔️ File T0864.txt sudah lengkap. Lewati.
# ✔️ File T0865.txt sudah lengkap. Lewati.
# ✔️ File T0866.txt sudah lengkap. Lewati.
# ✔️ File T0867.txt sudah lengkap. Lewati.
# ✔️ File T0868.txt sudah lengkap. Lewati.
# ✔️ File T0869.txt sudah lengkap. Lewati.
# Raw Response (Batch 1): ```json
# [
#     "Pada tahun 2019, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang tercatat sebanyak 51.683 jiwa, di Kecamatan Sukun sebanyak 25.600 jiwa, di Kecamatan Klojen sebanyak 58.157 jiwa, di Kecamatan Blimbing sebanyak 55.403 jiwa, dan di Kecamatan Lowokwaru sebanyak 43.867 jiwa. Dengan demikian, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 234.710 jiwa.",
#
#     "Di tahun 2019, jumlah penduduk (de jure) yang berumur 0-18 tahun dan memiliki akta kelahiran di Kecamatan Kedungkandang sebanyak 51.683 jiwa, sementara di Kecamatan Sukun mencapai 25.600 jiwa, di Kecamatan Klojen totalnya adalah 58.157 jiwa, di Kecamatan Blimbing tercatat 55.403 jiwa, dan di Kecamatan Lowokwaru berjumlah 43.867 jiwa. Oleh karenanya, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 234.710 jiwa.",
#
#     "Pada tahun 2019, penduduk (de jure) yang berusia 0-18 tahun dan memiliki akta kelahiran di Kecamatan Kedungkandang berjumlah 51.683 jiwa, di Kecamatan Sukun sebanyak 25.600 jiwa, di Kecamatan Klojen mencapai 58.157 jiwa, di Kecamatan Blimbing sebanyak 55.403 jiwa, dan di Kecamatan Lowokwaru sebanyak 43.867 jiwa. Dengan kata lain, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 234.710 jiwa.",
txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0870_20.txt
# ✔️ Batch 2 selesai. Menunggu 5 detik sebelum batch berikutnya...
# 🚀 Memproses Batch 3: 10 file...
# Raw Response (Batch 1): ```json
# [
#     "Pada tahun 2020, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang adalah sebanyak 51.883 jiwa, di Kecamatan Sukun sebanyak 25.828 jiwa, di Kecamatan Klojen mencapai 58.997 jiwa, di Kecamatan Blimbing sejumlah 55.822 jiwa, dan di Kecamatan Lowokwaru berjumlah 44.582 jiwa. Dengan demikian, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang mencapai 237.112 jiwa.",
#
#     "Di tahun 2020, jumlah penduduk (de jure) yang berusia 0-18 tahun dan memiliki akta kelahiran di Kecamatan Kedungkandang tercatat 51.883 jiwa, di Kecamatan Sukun 25.828 jiwa, di Kecamatan Klojen 58.997 jiwa, di Kecamatan Blimbing 55.822 jiwa, dan di Kecamatan Lowokwaru 44.582 jiwa. Maka, total penduduk (de jure) umur 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 237.112 jiwa.",
#
#     "Tahun 2020 mencatat jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang sebanyak 51.883 jiwa, di Kecamatan Sukun sebanyak 25.828 jiwa, di Kecamatan Klojen sebanyak 58.997 jiwa, di Kecamatan Blimbing mencapai 55.822 jiwa, dan di Kecamatan Lowokwaru sebanyak 44.582 jiwa. Oleh karena itu, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 237.112 jiwa.",
#
#     "Pada tahun 2020, penduduk (de jure) berusia 0-18 tahun yang terdaftar memiliki akta kelahiran di Kecamatan Kedungkandang sebanyak 51.883 jiwa, di Kecamatan Sukun sebanyak 25.828 jiwa, di Kecamatan Klojen sebanyak 58.997 jiwa, di Kecamatan Blimbing 55.822 jiwa, dan di Kecamatan Lowokwaru sebanyak 44.582 jiwa. Dengan demikian, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 237.112 jiwa.",
#
#     "Di tahun 2020, tercatat jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang sebanyak 51.883 jiwa, di Kecamatan Sukun 25.828 jiwa, di Kecamatan Klojen 58.997 jiwa, di Kecamatan Blimbing 55.822 jiwa, dan di Kecamatan Lowokwaru 44.582 jiwa. Maka, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 237.112 jiwa."
# ]
# ```
# Raw Response (Batch 2): [
#     "Pada tahun 2020, jumlah penduduk (De Jure) yang berusia 0-18 tahun dan memiliki akta kelahiran di Kecamatan Kedungkandang mencapai 51.883 jiwa, di Kecamatan Sukun sebanyak 25.828 jiwa, di Kecamatan Klojen sebesar 58.997 jiwa, di Kecamatan Blimbing sebanyak 55.822 jiwa, dan di Kecamatan Lowokwaru berjumlah 44.582 jiwa. Dengan demikian, jumlah penduduk (De Jure) umur 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 237.112 jiwa.",
#
#     "Pada tahun 2020, di Kecamatan Kedungkandang terdapat 51.883 jiwa penduduk (de jure) berumur 0-18 tahun yang memiliki akta kelahiran, di Kecamatan Sukun sebanyak 25.828 jiwa, di Kecamatan Klojen total 58.997 jiwa, di Kecamatan Blimbing 55.822 jiwa, dan di Kecamatan Lowokwaru sebanyak 44.582 jiwa. Dengan demikian, jumlah penduduk (de jure) dalam rentang usia 0-18 tahun yang memiliki akta kelahiran di Kota Malang ialah 237.112 jiwa.",
#
#     "Pada tahun 2020, di Kecamatan Kedungkandang jumlah penduduk (de jure) yang berusia 0-18 tahun dan memiliki akta kelahiran adalah 51.883 jiwa, sedangkan di Kecamatan Sukun ada 25.828 jiwa, di Kecamatan Klojen berjumlah 58.997 jiwa, di Kecamatan Blimbing 55.822 jiwa, dan di Kecamatan Lowokwaru sebanyak 44.582 jiwa. Oleh sebab itu, jumlah total penduduk (de jure) berusia 0-18 tahun dengan akta kelahiran di Kota Malang mencapai 237.112 jiwa."
# ]
# ```
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_1.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_2.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_3.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_4.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_5.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_6.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_7.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_8.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_9.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_10.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_11.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_12.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_13.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_14.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_15.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_16.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_17.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_18.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_19.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0871_20.txt
# Raw Response (Batch 1): ```json
# [
#     "Pada tahun 2021, jumlah penduduk (de jure) yang berusia 0-18 tahun dan memiliki akta kelahiran di Kecamatan Kedungkandang tercatat sebanyak 60.361 jiwa, di Kecamatan Sukun sebanyak 56.604 jiwa, di Kecamatan Klojen sebanyak 26.046 jiwa, di Kecamatan Blimbing sebanyak 52.367 jiwa, dan di Kecamatan Lowokwaru sebanyak 45.574 jiwa. Dengan demikian, total jumlah penduduk (de jure) umur 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 240.952 jiwa.",
#
#     "Pada tahun 2021, total penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang adalah 60.361 jiwa, di Kecamatan Sukun 56.604 jiwa, di Kecamatan Klojen 26.046 jiwa, di Kecamatan Blimbing 52.367 jiwa, dan di Kecamatan Lowokwaru 45.574 jiwa. Oleh karena itu, jumlah penduduk (de jure) umur 0-18 tahun yang memiliki akta kelahiran di Kota Malang mencapai 240.952 jiwa.",
#
#     "Di tahun 2021, jumlah penduduk (de jure) yang berumur 0-18 tahun dan mempunyai akta kelahiran di Kecamatan Kedungkandang adalah sebanyak 60.361 jiwa, sementara di Kecamatan Sukun jumlahnya 56.604 jiwa, di Kecamatan Klojen 26.046 jiwa, di Kecamatan Blimbing 52.367 jiwa, dan di Kecamatan Lowokwaru 45.574 jiwa. Maka, jumlah penduduk (de jure) umur 0-18 tahun yang memiliki akta kelahiran di Kota Malang berjumlah 240.952 jiwa.",
#
#     "Tahun 2021 menunjukkan bahwa jumlah penduduk (de jure) yang berusia 0-18 tahun dan memiliki akta kelahiran di Kecamatan Kedungkandang sebanyak 60.361 orang, di Kecamatan Sukun berjumlah 56.604 orang, di Kecamatan Klojen mencapai 26.046 orang, di Kecamatan Blimbing berjumlah 52.367 orang, dan di Kecamatan Lowokwaru tercatat 45.574 orang. Oleh karena itu, jumlah keseluruhan penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang mencapai 240.952 orang."
# ]
# ```
# Raw Response (Batch 3): ```json
# [
#     "Pada tahun 2021, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang adalah 60.361 jiwa, di Kecamatan Sukun tercatat sebanyak 56.604 jiwa, di Kecamatan Klojen sebanyak 26.046 jiwa, di Kecamatan Blimbing sejumlah 52.367 jiwa, dan di Kecamatan Lowokwaru mencapai 45.574 jiwa. Dengan demikian, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 240.952 jiwa.",
#
#     "Di tahun 2021, penduduk (de jure) dalam rentang umur 0-18 tahun yang mempunyai akta kelahiran di Kecamatan Kedungkandang mencapai 60.361 jiwa, di Kecamatan Sukun berjumlah 56.604 jiwa, di Kecamatan Klojen ada 26.046 jiwa, di Kecamatan Blimbing terdapat 52.367 jiwa, dan di Kecamatan Lowokwaru sebanyak 45.574 jiwa. Maka dari itu, total penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 240.952 jiwa.",
#
#     "Pada tahun 2021, jumlah individu (de jure) yang berumur antara 0 hingga 18 tahun dan memiliki akta kelahiran di Kecamatan Kedungkandang yakni 60.361 jiwa, di Kecamatan Sukun sebanyak 56.604 jiwa, di Kecamatan Klojen sejumlah 26.046 jiwa, di Kecamatan Blimbing terdiri dari 52.367 jiwa, dan di Kecamatan Lowokwaru terdaftar 45.574 jiwa. Oleh sebab itu, jumlah individu (de jure) umur 0-18 tahun yang memiliki akta kelahiran di Kota Malang mencapai 240.952 jiwa.",
#
#     "Di tahun 2021, jumlah populasi (de jure) yang berusia 0-18 tahun dan telah memiliki akta kelahiran di Kecamatan Kedungkandang adalah 60.361 jiwa, di Kecamatan Sukun terdapat 56.604 jiwa, di Kecamatan Klojen berjumlah 26.046 jiwa, di Kecamatan Blimbing mencapai 52.367 jiwa, dan di Kecamatan Lowokwaru sebanyak 45.574 jiwa. Dengan demikian, populasi (de jure) yang berumur 0-18 tahun dan memiliki akta kelahiran di Kota Malang adalah 240.952 jiwa.",
#
#     "Pada tahun 2021, penduduk (de jure) yang berusia antara 0 dan 18 tahun serta memiliki akta kelahiran di Kecamatan Kedungkandang tercatat sebanyak 60.361 jiwa, di Kecamatan Sukun mencapai 56.604 jiwa, di Kecamatan Klojen berjumlah 26.046 jiwa, di Kecamatan Blimbing terdapat 52.367 jiwa, dan di Kecamatan Lowokwaru sejumlah 45.574 jiwa. Jadi, jumlah penduduk (de jure) yang berusia 0-18 tahun dengan akta kelahiran di Kota Malang adalah 240.952 jiwa."
# ]
# ```
# Raw Response (Batch 4): ```json
# [
#     "Pada tahun 2021, jumlah penduduk (de jure) yang berusia 0-18 tahun dan memiliki akta kelahiran di Kecamatan Kedungkandang tercatat sebanyak 60.361 jiwa, di Kecamatan Sukun sebanyak 56.604 jiwa, di Kecamatan Klojen sebanyak 26.046 jiwa, di Kecamatan Blimbing sebanyak 52.367 jiwa, dan di Kecamatan Lowokwaru sebanyak 45.574 jiwa. Dengan demikian, total jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 240.952 jiwa.",
#
#     "Tahun 2021 mencatat bahwa jumlah penduduk (de jure) berumur 0-18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang mencapai 60.361 jiwa, di Kecamatan Sukun 56.604 jiwa, di Kecamatan Klojen 26.046 jiwa, di Kecamatan Blimbing 52.367 jiwa, dan di Kecamatan Lowokwaru 45.574 jiwa. Oleh karena itu, jumlah penduduk (de jure) umur 0-18 tahun dengan akta kelahiran di Kota Malang adalah 240.952 jiwa.",
#
#     "Di tahun 2021, jumlah penduduk (de jure) umur 0-18 tahun yang terdaftar memiliki akta kelahiran di Kecamatan Kedungkandang adalah 60.361 jiwa, di Kecamatan Sukun 56.604 jiwa, di Kecamatan Klojen 26.046 jiwa, di Kecamatan Blimbing 52.367 jiwa, serta di Kecamatan Lowokwaru 45.574 jiwa. Dengan demikian, jumlah keseluruhan penduduk (de jure) umur 0-18 tahun yang memiliki akta kelahiran di Kota Malang mencapai 240.952 jiwa.",
#
#     "Pada tahun 2021, tercatat jumlah penduduk (de jure) yang berusia antara 0 hingga 18 tahun dan memiliki akta kelahiran di Kecamatan Kedungkandang sebanyak 60.361 jiwa, di Kecamatan Sukun 56.604 jiwa, di Kecamatan Klojen 26.046 jiwa, di Kecamatan Blimbing 52.367 jiwa, dan di Kecamatan Lowokwaru 45.574 jiwa. Dengan cara ini, jumlah penduduk (de jure) umur 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 240.952 jiwa.",
#
#     "Tahun 2021 menunjukkan bahwa jumlah penduduk (de jure) yang berusia 0-18 tahun dan memiliki akta kelahiran di Kecamatan Kedungkandang sebanyak 60.361 jiwa, di Kecamatan Sukun 56.604 jiwa, di Kecamatan Klojen 26.046 jiwa, di Kecamatan Blimbing 52.367 jiwa, dan di Kecamatan Lowokwaru 45.574 jiwa. Sehingga, total penduduk (de jure) berumur 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 240.952 jiwa."
# ]
# ```
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_1.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_2.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_3.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_4.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_5.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_6.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_7.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_8.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_9.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_10.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_11.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_12.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_13.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_14.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_15.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_16.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_17.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_18.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_19.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0872_20.txt
# Raw Response (Batch 1): ```json
# [
#     "Pada tahun 2022, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang tercatat sebanyak 56.554 jiwa, di Kecamatan Sukun sebanyak 23.538 jiwa, di Kecamatan Klojen sejumlah 51.818 jiwa, di Kecamatan Blimbing sebanyak 47.423 jiwa, dan di Kecamatan Lowokwaru sebanyak 42.551 jiwa. Dengan demikian, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 221.884 jiwa.",
#
#     "Di tahun 2022, populasi penduduk (de jure) yang berusia 0-18 tahun dan telah memiliki akta kelahiran di Kecamatan Kedungkandang berjumlah 56.554 jiwa, di Kecamatan Sukun sejumlah 23.538 jiwa, di Kecamatan Klojen sebanyak 51.818 jiwa, di Kecamatan Blimbing dengan jumlah 47.423 jiwa, dan di Kecamatan Lowokwaru sebanyak 42.551 jiwa. Oleh karena itu, jumlah total penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang mencapai 221.884 jiwa.",
#
#     "Pada tahun 2022, jumlah penduduk (de jure) usia 0-18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang sebanyak 56.554 jiwa, sementara di Kecamatan Sukun sebanyak 23.538 jiwa, di Kecamatan Klojen tercatat 51.818 jiwa, di Kecamatan Blimbing berjumlah 47.423 jiwa, dan di Kecamatan Lowokwaru mencapai 42.551 jiwa. Dengan demikian, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 221.884 jiwa.",
#
#     "Dalam tahun 2022, terdapat jumlah penduduk (de jure) berumur 0-18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang sebanyak 56.554 jiwa, di Kecamatan Sukun sebanyak 23.538 jiwa, di Kecamatan Klojen sebanyak 51.818 jiwa, di Kecamatan Blimbing sebanyak 47.423 jiwa, serta di Kecamatan Lowokwaru yang berjumlah 42.551 jiwa. Oleh karena itu, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 221.884 jiwa.",
#
#     "Pada tahun 2022, jumlah penduduk (de jure) yang berada pada rentang usia 0-18 tahun dan memiliki akta kelahiran di Kecamatan Kedungkandang adalah 56.554 jiwa, di Kecamatan Sukun sebanyak 23.538 jiwa, di Kecamatan Klojen tercatat 51.818 jiwa, di Kecamatan Blimbing berjumlah 47.423 jiwa, dan di Kecamatan Lowokwaru sebanyak 42.551 jiwa. Maka, jumlah penduduk (de jure) yang berusia 0-18 tahun dan memiliki akta kelahiran di Kota Malang mencapai 221.884 jiwa."
# ]
# ```
# Raw Response (Batch 2): ```json
# [
#     "Pada tahun 2022, jumlah penduduk (de jure) yang berusia 0-18 tahun dan memiliki akta kelahiran di Kecamatan Kedungkandang tercatat sebanyak 56.554 jiwa, di Kecamatan Sukun sebanyak 23.538 jiwa, di Kecamatan Klojen mencapai 51.818 jiwa, di Kecamatan Blimbing sebanyak 47.423 jiwa, serta di Kecamatan Lowokwaru sebanyak 42.551 jiwa. Dengan demikian, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 221.884 jiwa.",
#
#     "Jumlah penduduk (De Jure) berusia 0-18 tahun yang memiliki akta kelahiran pada tahun 2022 di Kecamatan Kedungkandang adalah 56.554 jiwa, di Kecamatan Sukun sebanyak 23.538 jiwa, di Kecamatan Klojen sejumlah 51.818 jiwa, di Kecamatan Blimbing sebanyak 47.423 jiwa, dan di Kecamatan Lowokwaru mencapai 42.551 jiwa. Dengan demikian, penduduk (De Jure) berumur 0-18 tahun yang memiliki akta kelahiran di Kota Malang berjumlah 221.884 jiwa.",
#
#     "Di tahun 2022, jumlah penduduk (De Jure) yang berusia 0 hingga 18 tahun serta memiliki akta kelahiran di Kecamatan Kedungkandang adalah 56.554 jiwa, di Kecamatan Sukun sebanyak 23.538 jiwa, di Kecamatan Klojen berjumlah 51.818 jiwa, di Kecamatan Blimbing sebanyak 47.423 jiwa, dan di Kecamatan Lowokwaru sebanyak 42.551 jiwa. Maka, jumlah penduduk (De Jure) umur 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 221.884 jiwa."
# ]
# ```
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_1.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_2.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_3.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_4.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_5.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_6.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_7.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_8.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_9.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_10.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_11.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_12.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_13.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_14.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_15.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_16.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_17.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_18.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_19.txt
# ✅ Menyimpan file: /content/drive/My Drive/AYOK BIKIN DATASET/[04] PARAPHRASE DESCRIPTION [FIX]/D0873_20.txt
# Raw Response (Batch 1): ```json
# [
#     "Pada tahun 2023, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang tercatat sebanyak 59.340 jiwa, di Kecamatan Sukun sebanyak 53.751 jiwa, di Kecamatan Klojen sejumlah 24.295 jiwa, di Kecamatan Blimbing sebanyak 48.980 jiwa, dan di Kecamatan Lowokwaru sebanyak 43.878 jiwa. Dengan demikian, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang mencapai 230.244 jiwa.",
#
#     "Di tahun 2023, jumlah penduduk (de jure) dengan usia 0-18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang adalah 59.340 jiwa, di Kecamatan Sukun berjumlah 53.751 jiwa, di Kecamatan Klojen sebanyak 24.295 jiwa, di Kecamatan Blimbing mencapai 48.980 jiwa, dan di Kecamatan Lowokwaru sebanyak 43.878 jiwa. Oleh karena itu, total penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang ialah 230.244 jiwa.",
#
#     "Pada tahun 2023, penduduk (de jure) berusia antara 0 hingga 18 tahun yang memiliki akta kelahiran di Kecamatan Kedungkandang berjumlah 59.340 jiwa, di Kecamatan Sukun sebanyak 53.751 jiwa, di Kecamatan Klojen mencapai 24.295 jiwa, di Kecamatan Blimbing sebanyak 48.980 jiwa, dan di Kecamatan Lowokwaru sebanyak 43.878 jiwa. Dengan demikian, jumlah penduduk (de jure) berusia 0-18 tahun yang memiliki akta kelahiran di Kota Malang adalah 230.244 jiwa.",
#

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-19a5ce2255b1> in <cell line: 0>()
#      60
#      61     print(f"✔️ Batch {batch_number} selesai. Menunggu 5 detik sebelum batch berikutnya...")
# ---> 62     time.sleep(5)
#
# KeyboardInterrupt:

# %%
import random

# Path folder
folder_metadata = "/content/drive/My Drive/AYOK BIKIN DATASET/[00] METADATA"
folder_deskripsi = "/content/drive/My Drive/AYOK BIKIN DATASET/[03] DESCRIPTION"
folder_hasil = "/content/drive/My Drive/AYOK BIKIN DATASET/[05] TEST PARAPHRASE DESCRIPTION"

# Path metadata file
metadata_file = os.path.join(folder_metadata, "Metadata Tabel.xlsx")

# Output file untuk human evaluation
output_file = "/content/drive/My Drive/AYOK BIKIN DATASET/human_evaluation.xlsx"

# Ambil metadata
metadata_df = pd.read_excel(metadata_file)
metadata_df['Table ID'] = metadata_df['Table ID'].astype(str)

# Ambil daftar semua file deskripsi dan parafrase
file_deskripsi_list = sorted([f for f in os.listdir(folder_deskripsi) if f.endswith(".txt")])
file_parafrase_list = sorted([f for f in os.listdir(folder_hasil) if f.endswith(".txt")])

# Pilih 240 file parafrase secara acak
random_files = random.sample(file_parafrase_list, 240)

# Proses file untuk human evaluation
data = []
for parafrase_file in random_files:
    # Ambil ID tabel dari nama file
    id_tabel = parafrase_file.split("_")[0].replace("D", "T")  # Sesuaikan ID tabel ke format metadata

    # Ambil deskripsi base
    deskripsi_file = f"{id_tabel}.txt"
    path_deskripsi = os.path.join(folder_deskripsi, deskripsi_file)
    with open(path_deskripsi, "r", encoding="utf-8") as f:
        deskripsi_base = f.read().strip()

    # Ambil hasil parafrase
    path_parafrase = os.path.join(folder_hasil, parafrase_file)
    with open(path_parafrase, "r", encoding="utf-8") as f:
        hasil_parafrase = f.read().strip()

    # Tambahkan data ke list
    data.append({
        "Table ID": id_tabel,
        "Deskripsi Base": deskripsi_base,
        "Hasil Parafrase": hasil_parafrase,
        "Fluency": "",  # Kosong untuk diisi manual
        "Faithfulness/Accuracy": "",  # Kosong untuk diisi manual
        "Relevancy": ""  # Kosong untuk diisi manual
    })

# Simpan ke Excel
df = pd.DataFrame(data)
df.to_excel(output_file, index=False)

print(f"Human evaluation file saved to {output_file}")

# %%
# Evaluasi Otomatis
# !pip install -q rouge-score bert-score nltk scikit-learn
from rouge_score import rouge_scorer
from bert_score import score as bert_score
from nltk.translate.bleu_score import sentence_bleu
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
import csv

from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Download the 'punkt_tab' data for tokenization
nltk.download('punkt_tab')
nltk.download('punkt')

# Fungsi Evaluasi
def calculate_bleu(reference, candidate):
    reference_tokens = [nltk.word_tokenize(reference)]
    candidate_tokens = nltk.word_tokenize(candidate)
    return sentence_bleu(reference_tokens, candidate_tokens)

def calculate_rouge(reference, candidate):
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    scores = scorer.score(reference, candidate)
    return scores['rougeL'].fmeasure

def calculate_bert(reference, candidates):
    P, R, F1 = bert_score(candidates, [reference], lang="id")
    return float(F1.mean())

def calculate_cosine_similarity(reference, candidates):
    vectorizer = TfidfVectorizer().fit_transform([reference] + candidates)
    vectors = vectorizer.toarray()
    reference_vector = vectors[0]
    similarities = cosine_similarity([reference_vector], vectors[1:])
    return similarities.flatten().mean()

# Load IndoBERT tokenizer dan model
tokenizer = AutoTokenizer.from_pretrained("indobenchmark/indobert-base-p1")
model = AutoModel.from_pretrained("indobenchmark/indobert-base-p1")

# Fungsi untuk mendapatkan embedding
def get_embedding(text):
    tokens = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    with torch.no_grad():
        output = model(**tokens)
    # Mengambil mean dari last hidden state sebagai representasi vektor
    embedding = output.last_hidden_state.mean(dim=1).squeeze().numpy()
    return embedding

# Fungsi untuk menghitung cosine similarity menggunakan IndoBERT
def calculate_indobert_similarity(reference, candidates):
    ref_embedding = get_embedding(reference)
    cand_embeddings = np.array([get_embedding(cand) for cand in candidates])
    similarities = cosine_similarity([ref_embedding], cand_embeddings)
    return similarities.flatten().mean()
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 62.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 46.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 999.7 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 64.5 MB/s eta 0:00:00
#   Building wheel for rouge-score (setup.py) ... done
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/229k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]

# %%
# # Contoh penggunaan
# reference_text = "Pada tahun 2021, Jumlah Penduduk (De Jure) di Kecamatan Kedungkandang sebanyak 225.337 jiwa, di Kecamatan Sukun sebanyak 216.918 jiwa, di Kecamatan Klojen sebanyak 110.796 jiwa, di Kecamatan Blimbing sebanyak 203.380 jiwa, dan di Kecamatan Lowokwaru sebanyak 181.445 jiwa. Oleh karena itu, Jumlah Penduduk (De Jure) di Kota Malang sebanyak 937.876 jiwa."
# candidate_texts = [
#     "Pada tahun 2021, jumlah penduduk (De Jure) di Kecamatan Kedungkandang tercatat sebanyak 225.337 jiwa, di Kecamatan Sukun berjumlah 216.918 jiwa, di Kecamatan Klojen sebanyak 110.796 jiwa, di Kecamatan Blimbing mencapai 203.380 jiwa, dan di Kecamatan Lowokwaru sejumlah 181.445 jiwa. Dengan demikian, jumlah penduduk (De Jure) di Kota Malang adalah 937.876 jiwa.",
#     "Di tahun 2021, penduduk (De Jure) di Kecamatan Kedungkandang mencapai 225.337 jiwa, di Kecamatan Sukun tercatat 216.918 jiwa, di Kecamatan Klojen sebanyak 110.796 jiwa, di Kecamatan Blimbing berjumlah 203.380 jiwa, dan di Kecamatan Lowokwaru sebanyak 181.445 jiwa. Maka, total penduduk (De Jure) di Kota Malang adalah 937.876 jiwa.",
#     "Tahun 2021 mencatat jumlah penduduk (De Jure) di Kecamatan Kedungkandang sebanyak 225.337 jiwa, sedangkan di Kecamatan Sukun sejumlah 216.918 jiwa, di Kecamatan Klojen mencapai 110.796 jiwa, di Kecamatan Blimbing berjumlah 203.380 jiwa, dan di Kecamatan Lowokwaru sebanyak 181.445 jiwa. Oleh karena itu, jumlah penduduk (De Jure) di Kota Malang adalah 937.876 jiwa."
# ]

# similarity_score = calculate_indobert_similarity(reference_text, candidate_texts)
# print(f"IndoBERT Cosine Similarity: {similarity_score:.4f}")
# Out:
# IndoBERT Cosine Similarity: 0.9852

# %%
evaluation_results_path = os.path.join(folder_hasil, "evaluation_results.csv")

# Evaluasi Otomatis
file_deskripsi_list = sorted([f for f in os.listdir(folder_deskripsi) if f.endswith(".txt")])[0:100]

with open(evaluation_results_path, "w", newline="", encoding="utf-8") as eval_file:
    writer = csv.writer(eval_file)
    writer.writerow(["File", "BLEU", "ROUGE-L", "BERTScore", "Cosine Similarity", "IndoBERT Similarity"])

    for file_deskripsi in file_deskripsi_list:
        path_deskripsi = os.path.join(folder_deskripsi, file_deskripsi)
        with open(path_deskripsi, "r", encoding="utf-8") as f:
            deskripsi = f.read().strip()

        # Nama dasar file untuk mencocokkan parafrase
        base_filename = file_deskripsi.replace("T", "D").replace(".txt", "")
        parafrase_files = sorted(
            [f for f in os.listdir(folder_hasil) if f.startswith(base_filename)]
        )

        # Evaluasi setiap parafrase
        bleu_scores, rouge_scores, bert_scores, cosine_scores, indobert_scores = [], [], [], [], []
        for parafrase_file in parafrase_files:
            path_parafrase = os.path.join(folder_hasil, parafrase_file)
            with open(path_parafrase, "r", encoding="utf-8") as f_para:
                parafrase = f_para.read().strip()

            # Hitung metrik evaluasi
            bleu_scores.append(calculate_bleu(deskripsi, parafrase))
            rouge_scores.append(calculate_rouge(deskripsi, parafrase))
            bert_scores.append(calculate_bert(deskripsi, [parafrase]))
            cosine_scores.append(calculate_cosine_similarity(deskripsi, [parafrase]))
            indobert_scores.append(calculate_indobert_similarity(deskripsi, [parafrase]))

        # Rata-rata metrik untuk file ini
        avg_bleu = sum(bleu_scores) / len(bleu_scores)
        avg_rouge = sum(rouge_scores) / len(rouge_scores)
        avg_bert = sum(bert_scores) / len(bert_scores)
        avg_cosine = sum(cosine_scores) / len(cosine_scores)
        avg_indobert = sum(indobert_scores) / len(indobert_scores)

        # Tulis hasil evaluasi ke CSV
        writer.writerow([file_deskripsi, avg_bleu, avg_rouge, avg_bert, avg_cosine, avg_indobert])
        print(f"Evaluasi selesai untuk {file_deskripsi}.")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Evaluasi selesai untuk T0001.txt.
# Evaluasi selesai untuk T0002.txt.
# Evaluasi selesai untuk T0003.txt.
# Evaluasi selesai untuk T0004.txt.
# Evaluasi selesai untuk T0005.txt.
# Evaluasi selesai untuk T0006.txt.
# Evaluasi selesai untuk T0007.txt.
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Evaluasi selesai untuk T0008.txt.
# Evaluasi selesai untuk T0009.txt.
# Evaluasi selesai untuk T0010.txt.
# Evaluasi selesai untuk T0011.txt.
# Evaluasi selesai untuk T0012.txt.
# Evaluasi selesai untuk T0013.txt.
# Evaluasi selesai untuk T0014.txt.
# Evaluasi selesai untuk T0015.txt.
# Evaluasi selesai untuk T0016.txt.
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Evaluasi selesai untuk T0017.txt.
# Evaluasi selesai untuk T0018.txt.
# Evaluasi selesai untuk T0019.txt.
# Evaluasi selesai untuk T0020.txt.
# Evaluasi selesai untuk T0021.txt.
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Evaluasi selesai untuk T0022.txt.
# Evaluasi selesai untuk T0023.txt.
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Evaluasi selesai untuk T0024.txt.
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Evaluasi selesai untuk T0025.txt.
# Evaluasi selesai untuk T0026.txt.
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Evaluasi selesai untuk T0027.txt.
# Evaluasi selesai untuk T0028.txt.
# Evaluasi selesai untuk T0029.txt.
# Evaluasi selesai untuk T0030.txt.
# Evaluasi selesai untuk T0031.txt.
# Evaluasi selesai untuk T0032.txt.
# Evaluasi selesai untuk T0033.txt.
# Evaluasi selesai untuk T0034.txt.
# Evaluasi selesai untuk T0035.txt.
# Evaluasi selesai untuk T0036.txt.
# Evaluasi selesai untuk T0037.txt.
# Evaluasi selesai untuk T0038.txt.
# Evaluasi selesai untuk T0039.txt.
# Evaluasi selesai untuk T0040.txt.
# Evaluasi selesai untuk T0041.txt.
# Evaluasi selesai untuk T0042.txt.
# Evaluasi selesai untuk T0043.txt.
# Evaluasi selesai untuk T0044.txt.
# Evaluasi selesai untuk T0045.txt.
# Evaluasi selesai untuk T0046.txt.
# Evaluasi selesai untuk T0047.txt.
# Evaluasi selesai untuk T0048.txt.
# Evaluasi selesai untuk T0049.txt.
# Evaluasi selesai untuk T0050.txt.
# Evaluasi selesai untuk T0051.txt.
# Evaluasi selesai untuk T0052.txt.
# Evaluasi selesai untuk T0053.txt.
# Evaluasi selesai untuk T0054.txt.
# Evaluasi selesai untuk T0055.txt.
# Evaluasi selesai untuk T0056.txt.
# Evaluasi selesai untuk T0057.txt.
# Evaluasi selesai untuk T0058.txt.
# Evaluasi selesai untuk T0059.txt.
# Evaluasi selesai untuk T0060.txt.
# Evaluasi selesai untuk T0061.txt.
# Evaluasi selesai untuk T0062.txt.
# Evaluasi selesai untuk T0063.txt.
# Evaluasi selesai untuk T0064.txt.
# Evaluasi selesai untuk T0065.txt.
# Evaluasi selesai untuk T0066.txt.
# Evaluasi selesai untuk T0067.txt.
# Evaluasi selesai untuk T0068.txt.
# Evaluasi selesai untuk T0069.txt.
# Evaluasi selesai untuk T0070.txt.
# Evaluasi selesai untuk T0071.txt.
# Evaluasi selesai untuk T0072.txt.
# Evaluasi selesai untuk T0073.txt.
# Evaluasi selesai untuk T0074.txt.
# Evaluasi selesai untuk T0075.txt.
# Evaluasi selesai untuk T0076.txt.
# Evaluasi selesai untuk T0077.txt.
# Evaluasi selesai untuk T0078.txt.
# Evaluasi selesai untuk T0079.txt.
# Evaluasi selesai untuk T0080.txt.
# Evaluasi selesai untuk T0081.txt.
# Evaluasi selesai untuk T0082.txt.
# Evaluasi selesai untuk T0083.txt.
# Evaluasi selesai untuk T0084.txt.
# Evaluasi selesai untuk T0085.txt.
# Evaluasi selesai untuk T0086.txt.
# Evaluasi selesai untuk T0087.txt.
# Evaluasi selesai untuk T0088.txt.
# Evaluasi selesai untuk T0089.txt.
# Evaluasi selesai untuk T0090.txt.
# Evaluasi selesai untuk T0091.txt.
# Evaluasi selesai untuk T0092.txt.
# Evaluasi selesai untuk T0093.txt.
# Evaluasi selesai untuk T0094.txt.
# Evaluasi selesai untuk T0095.txt.
# Evaluasi selesai untuk T0096.txt.
# Evaluasi selesai untuk T0097.txt.
# Evaluasi selesai untuk T0098.txt.
# Evaluasi selesai untuk T0099.txt.
# Evaluasi selesai untuk T0100.txt.
