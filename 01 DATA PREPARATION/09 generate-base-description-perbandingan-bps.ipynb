# %% [markdown]
# ## Generate Base Description

# %%
import re
import json
import os
import pandas as pd
from typing import Tuple, Dict
from typing import Tuple, Dict, Any

def extract_params_from_title(title: str) -> Tuple[str, str, int]:
    """
    
    Extract the measurement title, unit, and year from the column title
    """

    def extract_short_title(title: str) -> str:
        """
        Extracts the short title by removing phrases like "Menurut Kecamatan di Kota Malang"
        or similar variations.
        """
        # Define the patterns to remove
        patterns = [
            r"\s*Menurut Kecamatan.*",
            r"/s*di Kota Malang.*"
        ]

        # Remove the patterns from the title
        for pattern in patterns:
            title = re.sub(pattern, "", title).strip()

        return title

    def extract_unit(title: str) -> str:
        """
        Extracts the unit from the title by finding the last occurrence of parentheses,
        handling nested parentheses cases.
        """
        if "(" not in title or ")" not in title:
            return ""

        stack = []
        last_unit = ""
        current_unit = ""
        in_parentheses = False

        for char in title:
            if char == '(':
                stack.append(char)
                if len(stack) == 1:
                    in_parentheses = True
                    current_unit = ""
                else:
                    current_unit += char
            elif char == ')':
                if not stack:
                    continue
                stack.pop()
                if stack:  # Still have open parentheses
                    current_unit += char
                else:  # Closed all parentheses
                    in_parentheses = False
                    last_unit = current_unit
            elif in_parentheses:
                current_unit += char

        return last_unit.strip()
    
    def extract_unit_flexible(title: str) -> str:
        title_lower = title.lower()
        if "meter kubik" in title_lower:
            return "m³"
        if "meter persegi" in title_lower:
            return "m²"
        if "jiwa/km2" in title_lower:
            return "jiwa/km²"
        if "hektar" in title_lower:
            return "ha"
        return extract_unit(title)

    def normalize_unit(unit: str) -> str:
        replacements = {
            r"^m3$": "m³",
            r"^m2$": "m²",
            r"km2$": "km²",
            r"ha$": "ha"
        }
        for pattern, repl in replacements.items():
            unit = re.sub(pattern, repl, unit.strip(), flags=re.IGNORECASE)
        return unit

    # Find year pattern (4 digits)
    year_match = re.search(r'\bTahun (\d{4})\b', title)
    year = int(year_match.group(1)) if year_match else None

    # Find unit pattern
    unit = extract_unit_flexible(title)
    unit = normalize_unit(unit)

    # Clean the title
    clean_title = extract_short_title(title)
    if year_match:
        clean_title = clean_title.replace(year_match.group(0), '').strip()
    if unit:
        clean_title = clean_title.replace(f'({unit})', '').strip()

    return clean_title, unit, year


def load_and_process_data(file_path: str, target_kota: str = "KOTA MALANG") -> Tuple[pd.DataFrame, Dict, Any]:
    """
    Load CSV file, process it, and extract parameters along with the 'KOTA MALANG' value.
    """
    df = pd.read_csv(file_path)
    columns = df.columns.tolist()
    value_column = columns[1]

    # Extract parameters
    title, unit, year = extract_params_from_title(value_column)

    # Get KOTA MALANG value and remove it
    kota_value = df.loc[df['Kecamatan'] == target_kota, value_column].values[0]
    df = df[df['Kecamatan'] != target_kota]
    df = df.set_index('Kecamatan')

    params = {
        'title': title,
        'unit': unit,
        'year': year,
        'value_column': value_column
    }
    return df, params, kota_value, target_kota


def define_adverb(title: str) -> str:
    rules = {
        "Jumlah": "sebanyak",
        "Luas": "sebesar",
        "Produksi": "sebanyak",
        "Daya": "sebesar",
        "Nilai": "sebesar",
        "Pertumbuhan": "sebesar",
        "Kepadatan": "sebesar",
        "Rasio": "sebesar",
        "Banyaknya": "sebanyak"
    }
    first_word = title.split()[0]
    return rules.get(first_word, "sebanyak")


def generate_base_description(df: pd.DataFrame, params: Dict, kota_value: Any, target_kota: str) -> str:
    def format_value(value: Any) -> str:
        def is_rupiah(unit: str) -> bool:
            return "Rp" in unit

        if isinstance(value, str):
            if value == '-':
                return value
            try:
                value = float(value)
            except ValueError:
                return value
        elif isinstance(value, int) or isinstance(value, float):
            value = float(value)

        # Format Indonesia: koma = desimal, titik = ribuan
        formatted = f"{value:,.2f}"
        formatted = formatted.replace(",", "X").replace(".", ",").replace("X", ".")
        formatted = formatted.rstrip("0").rstrip(",")
        
        if is_rupiah(params['unit']):
            return f"Rp{formatted}"
        return f"{formatted}"


    kata_keterangan = define_adverb(params['title'])

    # Identify districts without data
    no_data_mask = df[params['value_column']] == '-'
    no_data_districts = df[no_data_mask].index.tolist()

    df_with_data = df[~no_data_mask]
    sorted_df = df_with_data.sort_values(by=params['value_column'], ascending=False)

    highest = sorted_df.iloc[0]
    lowest = sorted_df.iloc[-1]
    middle = sorted_df.iloc[1:-1]

    # Build base description
    # desc = (
    #     f"Berdasarkan data tahun {params['year']}, {params['title']} tertinggi terdapat di Kecamatan {highest.name} "
    #     f"dengan nilai {kata_keterangan} {format_value(highest[params['value_column']])}"
    #     + ("" if "Rp" in params['unit'] else f" {params['unit']}")
    # )

    # if len(middle) > 0:
    #     for i, (d_name, row) in enumerate(middle.iterrows()):
    #         value_str = format_value(row[params['value_column']])
    #         unit_str = "" if "Rp" in params["unit"] else f" {params['unit']}"
            
    #         if i == 0:
    #             desc += f". Selanjutnya, Kecamatan {d_name} mencatatkan nilai {kata_keterangan} {value_str}{unit_str}"
    #         else:
    #             desc += f", Kecamatan {d_name} {kata_keterangan} {value_str}{unit_str}"

    # desc += (
    #     f". Sementara itu, {params['title']} paling rendah terdapat di Kecamatan {lowest.name} dengan nilai "
    #     f"{kata_keterangan} {format_value(lowest[params['value_column']])}"
    #     f"{'' if 'Rp' in params['unit'] else f' {params['unit']}' }."
    # )

    # if no_data_districts:
    #     if len(no_data_districts) == 1:
    #         desc += f" Terdapat catatan bahwa tidak tersedia data {params['title']} untuk Kecamatan {no_data_districts[0]}."
    #     else:
    #         names = ", ".join(no_data_districts)
    #         desc += f" Terdapat catatan bahwa tidak tersedia data {params['title']} untuk {names}."

    # # Tambahkan ringkasan KOTA MALANG
    # adverb_kota = define_adverb(params['title'])
    # fmt_kota = format_value(kota_value)
    # desc += (
    #     f" Dengan demikian, dapat disimpulkan bahwa {params['title']} untuk {target_kota.title()} {adverb_kota} "
    #     f"{fmt_kota} {params['unit']}.")

    desc = (
        f"Dengan demikian, Kecamatan {highest.name} memiliki {params['title']} tertinggi {kata_keterangan} "
        f"{format_value(highest[params['value_column']])}"
        f"{'' if 'Rp' in params['unit'] else f' {params['unit']}'}, "
        f"sedangkan Kecamatan {lowest.name} memiliki nilai terendah "
        f"{kata_keterangan} {format_value(lowest[params['value_column']])}"
        f"{'' if 'Rp' in params['unit'] else f' {params['unit']}'} di Kota Malang.")

    return desc

# %%
def detect_encoding(file_path):
    """Try different encodings to read the file"""
    encodings = ['utf-8', 'latin1', 'iso-8859-1', 'cp1252']

    for encoding in encodings:
        try:
            with open(file_path, 'r', encoding=encoding) as f:
                f.read()
            return encoding
        except UnicodeDecodeError:
            continue
    return None

def process_folder(input_folder_path: str, output_folder_path: str) -> None:
    os.makedirs(output_folder_path, exist_ok=True)
    csv_files = sorted([f for f in os.listdir(input_folder_path) if f.endswith('.csv')])

    for file_name in csv_files:
        try:
            input_file = os.path.join(input_folder_path, file_name)

            # Detect encoding
            encoding = detect_encoding(input_file)
            if not encoding:
                print(f"Could not detect encoding for {file_name}")
                continue

            # Read with detected encoding
            df = pd.read_csv(input_file, encoding=encoding)
            df, params, kota_value, target_kota = load_and_process_data(input_file)
            base_description = generate_base_description(df, params, kota_value, target_kota)

            base_filename = os.path.splitext(file_name)[0]
            result = {
                base_filename: {
                    "metadata": {
                        "title": params['title'],
                        "unit": params['unit'],
                        "year": params['year']
                    },
                    "base_description": base_description
                }
            }

            output_file = os.path.join(output_folder_path, f'{base_filename}.json')
            with open(output_file, 'w', encoding='utf-8') as f:
                json.dump(result, f, ensure_ascii=False, indent=2)

            # Simpan base_description ke dalam file .txt
            output_txt_file = os.path.join(output_folder_path, f'{base_filename}.txt')
            with open(output_txt_file, 'w', encoding='utf-8') as f:
                f.write(base_description)

            print(f"Successfully processed {file_name} with {encoding} encoding")

        except Exception as e:
            print(f"Error processing {file_name}: {str(e)}")
            continue

# %%
process_folder(
    input_folder_path='C:/Users/ASUS/OneDrive - Politeknik Statistika STIS/Dokumen/KULIAH/SEMESTER 7/[2] SKRIPSI/[4] PENGOLAHAN/Table Dataset',
    output_folder_path='C:/Users/ASUS/OneDrive - Politeknik Statistika STIS/Dokumen/KULIAH/SEMESTER 7/[2] SKRIPSI/[4] PENGOLAHAN/Generate Descriptions Version 2/base_tambahan_reasoning'
)
# Out:
# Successfully processed T0001.csv with utf-8 encoding
# Successfully processed T0002.csv with utf-8 encoding
# Successfully processed T0003.csv with utf-8 encoding
# Successfully processed T0004.csv with utf-8 encoding
# Successfully processed T0005.csv with utf-8 encoding
# Successfully processed T0006.csv with utf-8 encoding
# Successfully processed T0007.csv with utf-8 encoding
# Successfully processed T0008.csv with utf-8 encoding
# Successfully processed T0009.csv with utf-8 encoding
# Successfully processed T0010.csv with utf-8 encoding
# Successfully processed T0011.csv with utf-8 encoding
# Successfully processed T0012.csv with utf-8 encoding
# Successfully processed T0013.csv with utf-8 encoding
# Successfully processed T0014.csv with utf-8 encoding
# Successfully processed T0015.csv with utf-8 encoding
# Successfully processed T0016.csv with utf-8 encoding
# Successfully processed T0017.csv with utf-8 encoding
# Successfully processed T0018.csv with utf-8 encoding
# Successfully processed T0019.csv with utf-8 encoding
# Successfully processed T0020.csv with utf-8 encoding
# Successfully processed T0021.csv with utf-8 encoding
# Successfully processed T0022.csv with utf-8 encoding
# Successfully processed T0023.csv with utf-8 encoding
# Successfully processed T0024.csv with utf-8 encoding
# Successfully processed T0025.csv with utf-8 encoding
# Successfully processed T0026.csv with utf-8 encoding
# Successfully processed T0027.csv with utf-8 encoding
# Successfully processed T0028.csv with utf-8 encoding
# Successfully processed T0029.csv with utf-8 encoding
# Successfully processed T0030.csv with utf-8 encoding
# Successfully processed T0031.csv with utf-8 encoding
# Successfully processed T0032.csv with utf-8 encoding
# Successfully processed T0033.csv with utf-8 encoding
# Successfully processed T0034.csv with utf-8 encoding
# Successfully processed T0035.csv with utf-8 encoding
# Successfully processed T0036.csv with utf-8 encoding
# Successfully processed T0037.csv with utf-8 encoding
# Successfully processed T0038.csv with utf-8 encoding
# Successfully processed T0039.csv with utf-8 encoding
# Successfully processed T0040.csv with utf-8 encoding
# Successfully processed T0041.csv with utf-8 encoding
# Successfully processed T0042.csv with utf-8 encoding
# Successfully processed T0043.csv with utf-8 encoding
# Successfully processed T0044.csv with utf-8 encoding
# Successfully processed T0045.csv with utf-8 encoding
# Successfully processed T0046.csv with utf-8 encoding
# Successfully processed T0047.csv with utf-8 encoding
# Successfully processed T0048.csv with utf-8 encoding
# Successfully processed T0049.csv with utf-8 encoding
# Successfully processed T0050.csv with utf-8 encoding
# Successfully processed T0051.csv with utf-8 encoding
# Successfully processed T0052.csv with utf-8 encoding
# Successfully processed T0053.csv with utf-8 encoding
# Successfully processed T0054.csv with utf-8 encoding
# Successfully processed T0055.csv with utf-8 encoding
# Successfully processed T0056.csv with utf-8 encoding
# Successfully processed T0057.csv with utf-8 encoding
# Successfully processed T0058.csv with utf-8 encoding
# Successfully processed T0059.csv with utf-8 encoding
# Successfully processed T0060.csv with utf-8 encoding
# Successfully processed T0061.csv with utf-8 encoding
# Successfully processed T0062.csv with utf-8 encoding
# Successfully processed T0063.csv with utf-8 encoding
# Successfully processed T0064.csv with utf-8 encoding
# Successfully processed T0065.csv with utf-8 encoding
# Successfully processed T0066.csv with utf-8 encoding
# Successfully processed T0067.csv with utf-8 encoding
# Successfully processed T0068.csv with utf-8 encoding
# Successfully processed T0069.csv with utf-8 encoding
# Successfully processed T0070.csv with utf-8 encoding
# Successfully processed T0071.csv with utf-8 encoding
# Successfully processed T0072.csv with utf-8 encoding
# Successfully processed T0073.csv with utf-8 encoding
# Successfully processed T0074.csv with utf-8 encoding
# Successfully processed T0075.csv with utf-8 encoding
# Successfully processed T0076.csv with utf-8 encoding
# Successfully processed T0077.csv with utf-8 encoding
# Successfully processed T0078.csv with utf-8 encoding
# Successfully processed T0079.csv with utf-8 encoding
# Successfully processed T0080.csv with utf-8 encoding
# Successfully processed T0081.csv with utf-8 encoding
# Successfully processed T0082.csv with utf-8 encoding
# Successfully processed T0083.csv with utf-8 encoding
# Successfully processed T0084.csv with utf-8 encoding
# Successfully processed T0085.csv with utf-8 encoding
# Successfully processed T0086.csv with utf-8 encoding
# Successfully processed T0087.csv with utf-8 encoding
# Successfully processed T0088.csv with utf-8 encoding
# Successfully processed T0089.csv with utf-8 encoding
# Successfully processed T0090.csv with utf-8 encoding
# Successfully processed T0091.csv with utf-8 encoding
# Successfully processed T0092.csv with utf-8 encoding
# Successfully processed T0093.csv with utf-8 encoding
# Successfully processed T0094.csv with utf-8 encoding
# Successfully processed T0095.csv with utf-8 encoding
# Successfully processed T0096.csv with utf-8 encoding
# Successfully processed T0097.csv with utf-8 encoding
# Successfully processed T0098.csv with utf-8 encoding
# Successfully processed T0099.csv with utf-8 encoding
# Successfully processed T0100.csv with utf-8 encoding
# Successfully processed T0101.csv with utf-8 encoding
# Successfully processed T0102.csv with utf-8 encoding
# Successfully processed T0103.csv with utf-8 encoding
# Successfully processed T0104.csv with utf-8 encoding
# Successfully processed T0105.csv with utf-8 encoding
# Successfully processed T0106.csv with utf-8 encoding
# Successfully processed T0107.csv with utf-8 encoding
# Successfully processed T0108.csv with utf-8 encoding
# Successfully processed T0109.csv with utf-8 encoding
# Successfully processed T0110.csv with utf-8 encoding
# Successfully processed T0111.csv with utf-8 encoding
# Successfully processed T0112.csv with utf-8 encoding
# Successfully processed T0113.csv with utf-8 encoding
# Successfully processed T0114.csv with utf-8 encoding
# Successfully processed T0115.csv with utf-8 encoding
# Successfully processed T0116.csv with utf-8 encoding
# Successfully processed T0117.csv with utf-8 encoding
# Successfully processed T0118.csv with utf-8 encoding
# Successfully processed T0119.csv with utf-8 encoding
# Successfully processed T0120.csv with utf-8 encoding
# Successfully processed T0121.csv with utf-8 encoding
# Successfully processed T0122.csv with utf-8 encoding
# Successfully processed T0123.csv with utf-8 encoding
# Successfully processed T0124.csv with utf-8 encoding
# Successfully processed T0125.csv with utf-8 encoding
# Successfully processed T0126.csv with utf-8 encoding
# Successfully processed T0127.csv with utf-8 encoding
# Successfully processed T0128.csv with utf-8 encoding
# Successfully processed T0129.csv with utf-8 encoding
# Successfully processed T0130.csv with utf-8 encoding
# Successfully processed T0131.csv with utf-8 encoding
# Successfully processed T0132.csv with utf-8 encoding
# Successfully processed T0133.csv with utf-8 encoding
# Successfully processed T0134.csv with utf-8 encoding
# Successfully processed T0135.csv with utf-8 encoding
# Successfully processed T0136.csv with utf-8 encoding
# Successfully processed T0137.csv with utf-8 encoding
# Successfully processed T0138.csv with utf-8 encoding
# Successfully processed T0139.csv with utf-8 encoding
# Successfully processed T0140.csv with utf-8 encoding
# Successfully processed T0141.csv with utf-8 encoding
# Successfully processed T0142.csv with utf-8 encoding
# Successfully processed T0143.csv with utf-8 encoding
# Successfully processed T0144.csv with utf-8 encoding
# Successfully processed T0145.csv with utf-8 encoding
# Successfully processed T0146.csv with utf-8 encoding
# Successfully processed T0147.csv with utf-8 encoding
# Successfully processed T0148.csv with utf-8 encoding
# Successfully processed T0149.csv with utf-8 encoding
# Successfully processed T0150.csv with utf-8 encoding
# Successfully processed T0151.csv with utf-8 encoding
# Successfully processed T0152.csv with utf-8 encoding
# Successfully processed T0153.csv with utf-8 encoding
# Successfully processed T0154.csv with utf-8 encoding
# Successfully processed T0155.csv with utf-8 encoding
# Successfully processed T0156.csv with utf-8 encoding
# Successfully processed T0157.csv with utf-8 encoding
# Successfully processed T0158.csv with utf-8 encoding
# Successfully processed T0159.csv with utf-8 encoding
# Successfully processed T0160.csv with utf-8 encoding
# Successfully processed T0161.csv with utf-8 encoding
# Successfully processed T0162.csv with utf-8 encoding
# Successfully processed T0163.csv with utf-8 encoding
# Successfully processed T0164.csv with utf-8 encoding
# Successfully processed T0165.csv with utf-8 encoding
# Successfully processed T0166.csv with utf-8 encoding
# Successfully processed T0167.csv with utf-8 encoding
# Successfully processed T0168.csv with utf-8 encoding
# Successfully processed T0169.csv with utf-8 encoding
# Successfully processed T0170.csv with utf-8 encoding
# Successfully processed T0171.csv with utf-8 encoding
# Successfully processed T0172.csv with utf-8 encoding
# Successfully processed T0173.csv with utf-8 encoding
# Successfully processed T0174.csv with utf-8 encoding
# Successfully processed T0175.csv with utf-8 encoding
# Successfully processed T0176.csv with utf-8 encoding
# Successfully processed T0177.csv with utf-8 encoding
# Successfully processed T0178.csv with utf-8 encoding
# Successfully processed T0179.csv with utf-8 encoding
# Successfully processed T0180.csv with utf-8 encoding
# Successfully processed T0181.csv with utf-8 encoding
# Successfully processed T0182.csv with utf-8 encoding
# Successfully processed T0183.csv with utf-8 encoding
# Successfully processed T0184.csv with utf-8 encoding
# Successfully processed T0185.csv with utf-8 encoding
# Successfully processed T0186.csv with utf-8 encoding
# Successfully processed T0187.csv with utf-8 encoding
# Successfully processed T0188.csv with utf-8 encoding
# Successfully processed T0189.csv with utf-8 encoding
# Successfully processed T0190.csv with utf-8 encoding
# Successfully processed T0191.csv with utf-8 encoding
# Successfully processed T0192.csv with utf-8 encoding
# Successfully processed T0193.csv with utf-8 encoding
# Successfully processed T0194.csv with utf-8 encoding
# Successfully processed T0195.csv with utf-8 encoding
# Successfully processed T0196.csv with utf-8 encoding
# Successfully processed T0197.csv with utf-8 encoding
# Successfully processed T0198.csv with utf-8 encoding
# Successfully processed T0199.csv with utf-8 encoding
# Successfully processed T0200.csv with utf-8 encoding
# Successfully processed T0201.csv with utf-8 encoding
# Successfully processed T0202.csv with utf-8 encoding
# Successfully processed T0203.csv with utf-8 encoding
# Successfully processed T0204.csv with utf-8 encoding
# Successfully processed T0205.csv with utf-8 encoding
# Successfully processed T0206.csv with utf-8 encoding
# Successfully processed T0207.csv with utf-8 encoding
# Successfully processed T0208.csv with utf-8 encoding
# Successfully processed T0209.csv with utf-8 encoding
# Successfully processed T0210.csv with utf-8 encoding
# Successfully processed T0211.csv with utf-8 encoding
# Successfully processed T0212.csv with utf-8 encoding
# Successfully processed T0213.csv with utf-8 encoding
# Successfully processed T0214.csv with utf-8 encoding
# Successfully processed T0215.csv with utf-8 encoding
# Successfully processed T0216.csv with utf-8 encoding
# Successfully processed T0217.csv with utf-8 encoding
# Successfully processed T0218.csv with utf-8 encoding
# Successfully processed T0219.csv with utf-8 encoding
# Successfully processed T0220.csv with utf-8 encoding
# Successfully processed T0221.csv with utf-8 encoding
# Successfully processed T0222.csv with utf-8 encoding
# Successfully processed T0223.csv with utf-8 encoding
# Successfully processed T0224.csv with utf-8 encoding
# Successfully processed T0225.csv with utf-8 encoding
# Successfully processed T0226.csv with utf-8 encoding
# Successfully processed T0227.csv with utf-8 encoding
# Successfully processed T0228.csv with utf-8 encoding
# Successfully processed T0229.csv with utf-8 encoding
# Successfully processed T0230.csv with utf-8 encoding
# Successfully processed T0231.csv with utf-8 encoding
# Successfully processed T0232.csv with utf-8 encoding
# Successfully processed T0233.csv with utf-8 encoding
# Successfully processed T0234.csv with utf-8 encoding
# Successfully processed T0235.csv with utf-8 encoding
# Successfully processed T0236.csv with utf-8 encoding
# Successfully processed T0237.csv with utf-8 encoding
# Successfully processed T0238.csv with utf-8 encoding
# Successfully processed T0239.csv with utf-8 encoding
# Successfully processed T0240.csv with utf-8 encoding
# Successfully processed T0241.csv with utf-8 encoding
# Successfully processed T0242.csv with utf-8 encoding
# Successfully processed T0243.csv with utf-8 encoding
# Successfully processed T0244.csv with utf-8 encoding
# Successfully processed T0245.csv with utf-8 encoding
# Successfully processed T0246.csv with utf-8 encoding
# Successfully processed T0247.csv with utf-8 encoding
# Successfully processed T0248.csv with utf-8 encoding
# Successfully processed T0249.csv with utf-8 encoding
# Successfully processed T0250.csv with utf-8 encoding
# Successfully processed T0251.csv with utf-8 encoding
# Successfully processed T0252.csv with utf-8 encoding
# Successfully processed T0253.csv with utf-8 encoding
# Successfully processed T0254.csv with utf-8 encoding
# Successfully processed T0255.csv with utf-8 encoding
# Successfully processed T0256.csv with utf-8 encoding
# Successfully processed T0257.csv with utf-8 encoding
# Successfully processed T0258.csv with utf-8 encoding
# Successfully processed T0259.csv with utf-8 encoding
# Successfully processed T0260.csv with utf-8 encoding
# Successfully processed T0261.csv with utf-8 encoding
# Successfully processed T0262.csv with utf-8 encoding
# Successfully processed T0263.csv with utf-8 encoding
# Successfully processed T0264.csv with utf-8 encoding
# Successfully processed T0265.csv with utf-8 encoding
# Successfully processed T0266.csv with utf-8 encoding
# Successfully processed T0267.csv with utf-8 encoding
# Successfully processed T0268.csv with utf-8 encoding
# Successfully processed T0269.csv with utf-8 encoding
# Successfully processed T0270.csv with utf-8 encoding
# Successfully processed T0271.csv with utf-8 encoding
# Successfully processed T0272.csv with utf-8 encoding
# Successfully processed T0273.csv with utf-8 encoding
# Successfully processed T0274.csv with utf-8 encoding
# Successfully processed T0275.csv with utf-8 encoding
# Successfully processed T0276.csv with utf-8 encoding
# Successfully processed T0277.csv with utf-8 encoding
# Successfully processed T0278.csv with utf-8 encoding
# Successfully processed T0279.csv with utf-8 encoding
# Successfully processed T0280.csv with utf-8 encoding
# Successfully processed T0281.csv with utf-8 encoding
# Successfully processed T0282.csv with utf-8 encoding
# Successfully processed T0283.csv with utf-8 encoding
# Successfully processed T0284.csv with utf-8 encoding
# Successfully processed T0285.csv with utf-8 encoding
# Successfully processed T0286.csv with utf-8 encoding
# Successfully processed T0287.csv with utf-8 encoding
# Successfully processed T0288.csv with utf-8 encoding
# Successfully processed T0289.csv with utf-8 encoding
# Successfully processed T0290.csv with utf-8 encoding
# Successfully processed T0291.csv with utf-8 encoding
# Successfully processed T0292.csv with utf-8 encoding
# Successfully processed T0293.csv with utf-8 encoding
# Successfully processed T0294.csv with utf-8 encoding
# Successfully processed T0295.csv with utf-8 encoding
# Successfully processed T0296.csv with utf-8 encoding
# Successfully processed T0297.csv with utf-8 encoding
# Successfully processed T0298.csv with utf-8 encoding
# Successfully processed T0299.csv with utf-8 encoding
# Successfully processed T0300.csv with utf-8 encoding
# Successfully processed T0301.csv with utf-8 encoding
# Successfully processed T0302.csv with utf-8 encoding
# Successfully processed T0303.csv with utf-8 encoding
# Successfully processed T0304.csv with utf-8 encoding
# Successfully processed T0305.csv with utf-8 encoding
# Successfully processed T0306.csv with utf-8 encoding
# Successfully processed T0307.csv with utf-8 encoding
# Successfully processed T0308.csv with utf-8 encoding
# Successfully processed T0309.csv with utf-8 encoding
# Successfully processed T0310.csv with utf-8 encoding
# Successfully processed T0311.csv with utf-8 encoding
# Successfully processed T0312.csv with utf-8 encoding
# Successfully processed T0313.csv with utf-8 encoding
# Successfully processed T0314.csv with utf-8 encoding
# Successfully processed T0315.csv with utf-8 encoding
# Successfully processed T0316.csv with utf-8 encoding
# Successfully processed T0317.csv with utf-8 encoding
# Successfully processed T0318.csv with utf-8 encoding
# Successfully processed T0319.csv with utf-8 encoding
# Successfully processed T0320.csv with utf-8 encoding
# Successfully processed T0321.csv with utf-8 encoding
# Successfully processed T0322.csv with utf-8 encoding
# Successfully processed T0323.csv with utf-8 encoding
# Successfully processed T0324.csv with utf-8 encoding
# Successfully processed T0325.csv with utf-8 encoding
# Successfully processed T0326.csv with utf-8 encoding
# Successfully processed T0327.csv with utf-8 encoding
# Successfully processed T0328.csv with utf-8 encoding
# Successfully processed T0329.csv with utf-8 encoding
# Successfully processed T0330.csv with utf-8 encoding
# Successfully processed T0331.csv with utf-8 encoding
# Successfully processed T0332.csv with utf-8 encoding
# Successfully processed T0333.csv with utf-8 encoding
# Successfully processed T0334.csv with utf-8 encoding
# Successfully processed T0335.csv with utf-8 encoding
# Successfully processed T0336.csv with utf-8 encoding
# Successfully processed T0337.csv with utf-8 encoding
# Successfully processed T0338.csv with utf-8 encoding
# Successfully processed T0339.csv with utf-8 encoding
# Successfully processed T0340.csv with utf-8 encoding
# Successfully processed T0341.csv with utf-8 encoding
# Successfully processed T0342.csv with utf-8 encoding
# Successfully processed T0343.csv with utf-8 encoding
# Successfully processed T0344.csv with utf-8 encoding
# Successfully processed T0345.csv with utf-8 encoding
# Successfully processed T0346.csv with utf-8 encoding
# Successfully processed T0347.csv with utf-8 encoding
# Successfully processed T0348.csv with utf-8 encoding
# Successfully processed T0349.csv with utf-8 encoding
# Successfully processed T0350.csv with utf-8 encoding
# Successfully processed T0351.csv with utf-8 encoding
# Successfully processed T0352.csv with utf-8 encoding
# Successfully processed T0353.csv with utf-8 encoding
# Successfully processed T0354.csv with utf-8 encoding
# Successfully processed T0355.csv with utf-8 encoding
# Successfully processed T0356.csv with utf-8 encoding
# Successfully processed T0357.csv with utf-8 encoding
# Successfully processed T0358.csv with utf-8 encoding
# Successfully processed T0359.csv with utf-8 encoding
# Successfully processed T0360.csv with utf-8 encoding
# Successfully processed T0361.csv with utf-8 encoding
# Successfully processed T0362.csv with utf-8 encoding
# Successfully processed T0363.csv with utf-8 encoding
# Successfully processed T0364.csv with utf-8 encoding
# Successfully processed T0365.csv with utf-8 encoding
# Successfully processed T0366.csv with utf-8 encoding
# Successfully processed T0367.csv with utf-8 encoding
# Successfully processed T0368.csv with utf-8 encoding
# Successfully processed T0369.csv with utf-8 encoding
# Successfully processed T0370.csv with utf-8 encoding
# Successfully processed T0371.csv with utf-8 encoding
# Successfully processed T0372.csv with utf-8 encoding
# Successfully processed T0373.csv with utf-8 encoding
# Successfully processed T0374.csv with utf-8 encoding
# Successfully processed T0375.csv with utf-8 encoding
# Successfully processed T0376.csv with utf-8 encoding
# Successfully processed T0377.csv with utf-8 encoding
# Successfully processed T0378.csv with utf-8 encoding
# Successfully processed T0379.csv with utf-8 encoding
# Successfully processed T0380.csv with utf-8 encoding
# Successfully processed T0381.csv with utf-8 encoding
# Successfully processed T0382.csv with utf-8 encoding
# Successfully processed T0383.csv with utf-8 encoding
# Successfully processed T0384.csv with utf-8 encoding
# Successfully processed T0385.csv with utf-8 encoding
# Successfully processed T0386.csv with utf-8 encoding
# Successfully processed T0387.csv with utf-8 encoding
# Successfully processed T0388.csv with utf-8 encoding
# Successfully processed T0389.csv with utf-8 encoding
# Successfully processed T0390.csv with utf-8 encoding
# Successfully processed T0391.csv with utf-8 encoding
# Successfully processed T0392.csv with utf-8 encoding
# Successfully processed T0393.csv with utf-8 encoding
# Successfully processed T0394.csv with utf-8 encoding
# Successfully processed T0395.csv with utf-8 encoding
# Successfully processed T0396.csv with utf-8 encoding
# Successfully processed T0397.csv with utf-8 encoding
# Successfully processed T0398.csv with utf-8 encoding
# Successfully processed T0399.csv with utf-8 encoding
# Successfully processed T0400.csv with utf-8 encoding
# Successfully processed T0401.csv with utf-8 encoding
# Successfully processed T0402.csv with utf-8 encoding
# Successfully processed T0403.csv with utf-8 encoding
# Successfully processed T0404.csv with utf-8 encoding
# Successfully processed T0405.csv with utf-8 encoding
# Successfully processed T0406.csv with utf-8 encoding
# Successfully processed T0407.csv with utf-8 encoding
# Successfully processed T0408.csv with utf-8 encoding
# Successfully processed T0409.csv with utf-8 encoding
# Successfully processed T0410.csv with utf-8 encoding
# Successfully processed T0411.csv with utf-8 encoding
# Successfully processed T0412.csv with utf-8 encoding
# Successfully processed T0413.csv with utf-8 encoding
# Successfully processed T0414.csv with utf-8 encoding
# Successfully processed T0415.csv with utf-8 encoding
# Successfully processed T0416.csv with utf-8 encoding
# Successfully processed T0417.csv with utf-8 encoding
# Successfully processed T0418.csv with utf-8 encoding
# Successfully processed T0419.csv with utf-8 encoding
# Successfully processed T0420.csv with utf-8 encoding
# Successfully processed T0421.csv with utf-8 encoding
# Successfully processed T0422.csv with utf-8 encoding
# Successfully processed T0423.csv with utf-8 encoding
# Successfully processed T0424.csv with utf-8 encoding
# Successfully processed T0425.csv with utf-8 encoding
# Successfully processed T0426.csv with utf-8 encoding
# Successfully processed T0427.csv with utf-8 encoding
# Successfully processed T0428.csv with utf-8 encoding
# Successfully processed T0429.csv with utf-8 encoding
# Successfully processed T0430.csv with utf-8 encoding
# Successfully processed T0431.csv with utf-8 encoding
# Successfully processed T0432.csv with utf-8 encoding
# Successfully processed T0433.csv with utf-8 encoding
# Successfully processed T0434.csv with utf-8 encoding
# Successfully processed T0435.csv with utf-8 encoding
# Successfully processed T0436.csv with utf-8 encoding
# Successfully processed T0437.csv with utf-8 encoding
# Successfully processed T0438.csv with utf-8 encoding
# Successfully processed T0439.csv with utf-8 encoding
# Successfully processed T0440.csv with utf-8 encoding
# Successfully processed T0441.csv with utf-8 encoding
# Successfully processed T0442.csv with utf-8 encoding
# Successfully processed T0443.csv with utf-8 encoding
# Successfully processed T0444.csv with utf-8 encoding
# Successfully processed T0445.csv with utf-8 encoding
# Successfully processed T0446.csv with utf-8 encoding
# Successfully processed T0447.csv with utf-8 encoding
# Successfully processed T0448.csv with utf-8 encoding
# Successfully processed T0449.csv with utf-8 encoding
# Successfully processed T0450.csv with utf-8 encoding
# Successfully processed T0451.csv with utf-8 encoding
# Successfully processed T0452.csv with utf-8 encoding
# Successfully processed T0453.csv with utf-8 encoding
# Successfully processed T0454.csv with utf-8 encoding
# Successfully processed T0455.csv with utf-8 encoding
# Successfully processed T0456.csv with utf-8 encoding
# Successfully processed T0457.csv with utf-8 encoding
# Successfully processed T0458.csv with utf-8 encoding
# Successfully processed T0459.csv with utf-8 encoding
# Successfully processed T0460.csv with utf-8 encoding
# Successfully processed T0461.csv with utf-8 encoding
# Successfully processed T0462.csv with utf-8 encoding
# Successfully processed T0463.csv with utf-8 encoding
# Successfully processed T0464.csv with utf-8 encoding
# Successfully processed T0465.csv with utf-8 encoding
# Successfully processed T0466.csv with utf-8 encoding
# Successfully processed T0467.csv with utf-8 encoding
# Successfully processed T0468.csv with utf-8 encoding
# Successfully processed T0469.csv with utf-8 encoding
# Successfully processed T0470.csv with utf-8 encoding
# Successfully processed T0471.csv with utf-8 encoding
# Successfully processed T0472.csv with utf-8 encoding
# Successfully processed T0473.csv with utf-8 encoding
# Successfully processed T0474.csv with utf-8 encoding
# Successfully processed T0475.csv with utf-8 encoding
# Successfully processed T0476.csv with utf-8 encoding
# Successfully processed T0477.csv with utf-8 encoding
# Successfully processed T0478.csv with utf-8 encoding
# Successfully processed T0479.csv with utf-8 encoding
# Successfully processed T0480.csv with utf-8 encoding
# Successfully processed T0481.csv with utf-8 encoding
# Successfully processed T0482.csv with utf-8 encoding
# Successfully processed T0483.csv with utf-8 encoding
# Successfully processed T0484.csv with utf-8 encoding
# Successfully processed T0485.csv with utf-8 encoding
# Successfully processed T0486.csv with utf-8 encoding
# Successfully processed T0487.csv with utf-8 encoding
# Successfully processed T0488.csv with utf-8 encoding
# Successfully processed T0489.csv with utf-8 encoding
# Successfully processed T0490.csv with utf-8 encoding
# Successfully processed T0491.csv with utf-8 encoding
# Successfully processed T0492.csv with utf-8 encoding
# Successfully processed T0493.csv with utf-8 encoding
# Successfully processed T0494.csv with utf-8 encoding
# Successfully processed T0495.csv with utf-8 encoding
# Successfully processed T0496.csv with utf-8 encoding
# Successfully processed T0497.csv with utf-8 encoding
# Successfully processed T0498.csv with utf-8 encoding
# Successfully processed T0499.csv with utf-8 encoding
# Successfully processed T0500.csv with utf-8 encoding
# Successfully processed T0501.csv with utf-8 encoding
# Successfully processed T0502.csv with utf-8 encoding
# Successfully processed T0503.csv with utf-8 encoding
# Successfully processed T0504.csv with utf-8 encoding
# Successfully processed T0505.csv with utf-8 encoding
# Successfully processed T0506.csv with utf-8 encoding
# Successfully processed T0507.csv with utf-8 encoding
# Successfully processed T0508.csv with utf-8 encoding
# Successfully processed T0509.csv with utf-8 encoding
# Successfully processed T0510.csv with utf-8 encoding
# Successfully processed T0511.csv with utf-8 encoding
# Successfully processed T0512.csv with utf-8 encoding
# Successfully processed T0513.csv with utf-8 encoding
# Successfully processed T0514.csv with utf-8 encoding
# Successfully processed T0515.csv with utf-8 encoding
# Successfully processed T0516.csv with utf-8 encoding
# Successfully processed T0517.csv with utf-8 encoding
# Successfully processed T0518.csv with utf-8 encoding
# Successfully processed T0519.csv with utf-8 encoding
# Successfully processed T0520.csv with utf-8 encoding
# Successfully processed T0521.csv with utf-8 encoding
# Successfully processed T0522.csv with utf-8 encoding
# Successfully processed T0523.csv with utf-8 encoding
# Successfully processed T0524.csv with utf-8 encoding
# Successfully processed T0525.csv with utf-8 encoding
# Successfully processed T0526.csv with utf-8 encoding
# Successfully processed T0527.csv with utf-8 encoding
# Successfully processed T0528.csv with utf-8 encoding
# Successfully processed T0529.csv with utf-8 encoding
# Successfully processed T0530.csv with utf-8 encoding
# Successfully processed T0531.csv with utf-8 encoding
# Successfully processed T0532.csv with utf-8 encoding
# Successfully processed T0533.csv with utf-8 encoding
# Successfully processed T0534.csv with utf-8 encoding
# Successfully processed T0535.csv with utf-8 encoding
# Successfully processed T0536.csv with utf-8 encoding
# Successfully processed T0537.csv with utf-8 encoding
# Successfully processed T0538.csv with utf-8 encoding
# Successfully processed T0539.csv with utf-8 encoding
# Successfully processed T0540.csv with utf-8 encoding
# Successfully processed T0541.csv with utf-8 encoding
# Successfully processed T0542.csv with utf-8 encoding
# Successfully processed T0543.csv with utf-8 encoding
# Successfully processed T0544.csv with utf-8 encoding
# Successfully processed T0545.csv with utf-8 encoding
# Successfully processed T0546.csv with utf-8 encoding
# Successfully processed T0547.csv with utf-8 encoding
# Successfully processed T0548.csv with utf-8 encoding
# Successfully processed T0549.csv with utf-8 encoding
# Successfully processed T0550.csv with utf-8 encoding
# Successfully processed T0551.csv with utf-8 encoding
# Successfully processed T0552.csv with utf-8 encoding
# Successfully processed T0553.csv with utf-8 encoding
# Successfully processed T0554.csv with utf-8 encoding
# Successfully processed T0555.csv with utf-8 encoding
# Successfully processed T0556.csv with utf-8 encoding
# Successfully processed T0557.csv with utf-8 encoding
# Successfully processed T0558.csv with utf-8 encoding
# Successfully processed T0559.csv with utf-8 encoding
# Successfully processed T0560.csv with utf-8 encoding
# Successfully processed T0561.csv with utf-8 encoding
# Successfully processed T0562.csv with utf-8 encoding
# Successfully processed T0563.csv with utf-8 encoding
# Successfully processed T0564.csv with utf-8 encoding
# Successfully processed T0565.csv with utf-8 encoding
# Successfully processed T0566.csv with utf-8 encoding
# Successfully processed T0567.csv with utf-8 encoding
# Successfully processed T0568.csv with utf-8 encoding
# Successfully processed T0569.csv with utf-8 encoding
# Successfully processed T0570.csv with utf-8 encoding
# Successfully processed T0571.csv with utf-8 encoding
# Successfully processed T0572.csv with utf-8 encoding
# Successfully processed T0573.csv with utf-8 encoding
# Successfully processed T0574.csv with utf-8 encoding
# Successfully processed T0575.csv with utf-8 encoding
# Successfully processed T0576.csv with utf-8 encoding
# Successfully processed T0577.csv with utf-8 encoding
# Successfully processed T0578.csv with utf-8 encoding
# Successfully processed T0579.csv with utf-8 encoding
# Successfully processed T0580.csv with utf-8 encoding
# Successfully processed T0581.csv with utf-8 encoding
# Successfully processed T0582.csv with utf-8 encoding
# Successfully processed T0583.csv with utf-8 encoding
# Successfully processed T0584.csv with utf-8 encoding
# Successfully processed T0585.csv with utf-8 encoding
# Successfully processed T0586.csv with utf-8 encoding
# Successfully processed T0587.csv with utf-8 encoding
# Successfully processed T0588.csv with utf-8 encoding
# Successfully processed T0589.csv with utf-8 encoding
# Successfully processed T0590.csv with utf-8 encoding
# Successfully processed T0591.csv with utf-8 encoding
# Successfully processed T0592.csv with utf-8 encoding
# Successfully processed T0593.csv with utf-8 encoding
# Successfully processed T0594.csv with utf-8 encoding
# Successfully processed T0595.csv with utf-8 encoding
# Successfully processed T0596.csv with utf-8 encoding
# Successfully processed T0597.csv with utf-8 encoding
# Successfully processed T0598.csv with utf-8 encoding
# Successfully processed T0599.csv with utf-8 encoding
# Successfully processed T0600.csv with utf-8 encoding
# Successfully processed T0601.csv with utf-8 encoding
# Successfully processed T0602.csv with utf-8 encoding
# Successfully processed T0603.csv with utf-8 encoding
# Successfully processed T0604.csv with utf-8 encoding
# Successfully processed T0605.csv with utf-8 encoding
# Successfully processed T0606.csv with utf-8 encoding
# Successfully processed T0607.csv with utf-8 encoding
# Successfully processed T0608.csv with utf-8 encoding
# Successfully processed T0609.csv with utf-8 encoding
# Successfully processed T0610.csv with utf-8 encoding
# Successfully processed T0611.csv with utf-8 encoding
# Successfully processed T0612.csv with utf-8 encoding
# Successfully processed T0613.csv with utf-8 encoding
# Successfully processed T0614.csv with utf-8 encoding
# Successfully processed T0615.csv with utf-8 encoding
# Successfully processed T0616.csv with utf-8 encoding
# Successfully processed T0617.csv with utf-8 encoding
# Successfully processed T0618.csv with utf-8 encoding
# Successfully processed T0619.csv with utf-8 encoding
# Successfully processed T0620.csv with utf-8 encoding
# Successfully processed T0621.csv with utf-8 encoding
# Successfully processed T0622.csv with utf-8 encoding
# Successfully processed T0623.csv with utf-8 encoding
# Successfully processed T0624.csv with utf-8 encoding
# Successfully processed T0625.csv with utf-8 encoding
# Successfully processed T0626.csv with utf-8 encoding
# Successfully processed T0627.csv with utf-8 encoding
# Successfully processed T0628.csv with utf-8 encoding
# Successfully processed T0629.csv with utf-8 encoding
# Successfully processed T0630.csv with utf-8 encoding
# Successfully processed T0631.csv with utf-8 encoding
# Successfully processed T0632.csv with utf-8 encoding
# Successfully processed T0633.csv with utf-8 encoding
# Successfully processed T0634.csv with utf-8 encoding
# Successfully processed T0635.csv with utf-8 encoding
# Successfully processed T0636.csv with utf-8 encoding
# Successfully processed T0637.csv with utf-8 encoding
# Successfully processed T0638.csv with utf-8 encoding
# Successfully processed T0639.csv with utf-8 encoding
# Successfully processed T0640.csv with utf-8 encoding
# Successfully processed T0641.csv with utf-8 encoding
# Successfully processed T0642.csv with utf-8 encoding
# Successfully processed T0643.csv with utf-8 encoding
# Successfully processed T0644.csv with utf-8 encoding
# Successfully processed T0645.csv with utf-8 encoding
# Successfully processed T0646.csv with utf-8 encoding
# Successfully processed T0647.csv with utf-8 encoding
# Successfully processed T0648.csv with utf-8 encoding
# Successfully processed T0649.csv with utf-8 encoding
# Successfully processed T0650.csv with utf-8 encoding
# Successfully processed T0651.csv with utf-8 encoding
# Successfully processed T0652.csv with utf-8 encoding
# Successfully processed T0653.csv with utf-8 encoding
# Successfully processed T0654.csv with utf-8 encoding
# Successfully processed T0655.csv with utf-8 encoding
# Successfully processed T0656.csv with utf-8 encoding
# Successfully processed T0657.csv with utf-8 encoding
# Successfully processed T0658.csv with utf-8 encoding
# Successfully processed T0659.csv with utf-8 encoding
# Successfully processed T0660.csv with utf-8 encoding
# Successfully processed T0661.csv with utf-8 encoding
# Successfully processed T0662.csv with utf-8 encoding
# Successfully processed T0663.csv with utf-8 encoding
# Successfully processed T0664.csv with utf-8 encoding
# Successfully processed T0665.csv with utf-8 encoding
# Successfully processed T0666.csv with utf-8 encoding
# Successfully processed T0667.csv with utf-8 encoding
# Successfully processed T0668.csv with utf-8 encoding
# Successfully processed T0669.csv with utf-8 encoding
# Successfully processed T0670.csv with utf-8 encoding
# Successfully processed T0671.csv with utf-8 encoding
# Successfully processed T0672.csv with utf-8 encoding
# Successfully processed T0673.csv with utf-8 encoding
# Successfully processed T0674.csv with utf-8 encoding
# Successfully processed T0675.csv with utf-8 encoding
# Successfully processed T0676.csv with utf-8 encoding
# Successfully processed T0677.csv with utf-8 encoding
# Successfully processed T0678.csv with utf-8 encoding
# Successfully processed T0679.csv with utf-8 encoding
# Successfully processed T0680.csv with utf-8 encoding
# Successfully processed T0681.csv with utf-8 encoding
# Successfully processed T0682.csv with utf-8 encoding
# Successfully processed T0683.csv with utf-8 encoding
# Successfully processed T0684.csv with utf-8 encoding
# Successfully processed T0685.csv with utf-8 encoding
# Successfully processed T0686.csv with utf-8 encoding
# Successfully processed T0687.csv with utf-8 encoding
# Successfully processed T0688.csv with utf-8 encoding
# Successfully processed T0689.csv with utf-8 encoding
# Successfully processed T0690.csv with utf-8 encoding
# Successfully processed T0691.csv with utf-8 encoding
# Successfully processed T0692.csv with utf-8 encoding
# Successfully processed T0693.csv with utf-8 encoding
# Successfully processed T0694.csv with utf-8 encoding
# Successfully processed T0695.csv with utf-8 encoding
# Successfully processed T0696.csv with utf-8 encoding
# Successfully processed T0697.csv with utf-8 encoding
# Successfully processed T0698.csv with utf-8 encoding
# Successfully processed T0699.csv with utf-8 encoding
# Successfully processed T0700.csv with utf-8 encoding
# Successfully processed T0701.csv with utf-8 encoding
# Successfully processed T0702.csv with utf-8 encoding
# Successfully processed T0703.csv with utf-8 encoding
# Successfully processed T0704.csv with utf-8 encoding
# Successfully processed T0705.csv with utf-8 encoding
# Successfully processed T0706.csv with utf-8 encoding
# Successfully processed T0707.csv with utf-8 encoding
# Successfully processed T0708.csv with utf-8 encoding
# Successfully processed T0709.csv with utf-8 encoding
# Successfully processed T0710.csv with utf-8 encoding
# Successfully processed T0711.csv with utf-8 encoding
# Successfully processed T0712.csv with utf-8 encoding
# Successfully processed T0713.csv with utf-8 encoding
# Successfully processed T0714.csv with utf-8 encoding
# Successfully processed T0715.csv with utf-8 encoding
# Successfully processed T0716.csv with utf-8 encoding
# Successfully processed T0717.csv with utf-8 encoding
# Successfully processed T0718.csv with utf-8 encoding
# Successfully processed T0719.csv with utf-8 encoding
# Successfully processed T0720.csv with utf-8 encoding
# Successfully processed T0721.csv with utf-8 encoding
# Successfully processed T0722.csv with utf-8 encoding
# Successfully processed T0723.csv with utf-8 encoding
# Successfully processed T0724.csv with utf-8 encoding
# Successfully processed T0725.csv with utf-8 encoding
# Successfully processed T0726.csv with utf-8 encoding
# Successfully processed T0727.csv with utf-8 encoding
# Successfully processed T0728.csv with utf-8 encoding
# Successfully processed T0729.csv with utf-8 encoding
# Successfully processed T0730.csv with utf-8 encoding
# Successfully processed T0731.csv with utf-8 encoding
# Successfully processed T0732.csv with utf-8 encoding
# Successfully processed T0733.csv with utf-8 encoding
# Successfully processed T0734.csv with utf-8 encoding
# Successfully processed T0735.csv with utf-8 encoding
# Successfully processed T0736.csv with utf-8 encoding
# Successfully processed T0737.csv with utf-8 encoding
# Successfully processed T0738.csv with utf-8 encoding
# Successfully processed T0739.csv with utf-8 encoding
# Successfully processed T0740.csv with utf-8 encoding
# Successfully processed T0741.csv with utf-8 encoding
# Successfully processed T0742.csv with utf-8 encoding
# Successfully processed T0743.csv with utf-8 encoding
# Successfully processed T0744.csv with utf-8 encoding
# Successfully processed T0745.csv with utf-8 encoding
# Successfully processed T0746.csv with utf-8 encoding
# Successfully processed T0747.csv with utf-8 encoding
# Successfully processed T0748.csv with utf-8 encoding
# Successfully processed T0749.csv with utf-8 encoding
# Successfully processed T0750.csv with utf-8 encoding
# Successfully processed T0751.csv with utf-8 encoding
# Successfully processed T0752.csv with utf-8 encoding
# Successfully processed T0753.csv with utf-8 encoding
# Successfully processed T0754.csv with utf-8 encoding
# Successfully processed T0755.csv with utf-8 encoding
# Successfully processed T0756.csv with utf-8 encoding
# Successfully processed T0757.csv with utf-8 encoding
# Successfully processed T0758.csv with utf-8 encoding
# Successfully processed T0759.csv with utf-8 encoding
# Successfully processed T0760.csv with utf-8 encoding
# Successfully processed T0761.csv with utf-8 encoding
# Successfully processed T0762.csv with utf-8 encoding
# Successfully processed T0763.csv with utf-8 encoding
# Successfully processed T0764.csv with utf-8 encoding
# Successfully processed T0765.csv with utf-8 encoding
# Successfully processed T0766.csv with utf-8 encoding
# Successfully processed T0767.csv with utf-8 encoding
# Successfully processed T0768.csv with utf-8 encoding
# Successfully processed T0769.csv with utf-8 encoding
# Successfully processed T0770.csv with utf-8 encoding
# Successfully processed T0771.csv with utf-8 encoding
# Successfully processed T0772.csv with utf-8 encoding
# Successfully processed T0773.csv with utf-8 encoding
# Successfully processed T0774.csv with utf-8 encoding
# Successfully processed T0775.csv with utf-8 encoding
# Successfully processed T0776.csv with utf-8 encoding
# Successfully processed T0777.csv with utf-8 encoding
# Successfully processed T0778.csv with utf-8 encoding
# Successfully processed T0779.csv with utf-8 encoding
# Successfully processed T0780.csv with utf-8 encoding
# Successfully processed T0781.csv with utf-8 encoding
# Successfully processed T0782.csv with utf-8 encoding
# Successfully processed T0783.csv with utf-8 encoding
# Successfully processed T0784.csv with utf-8 encoding
# Successfully processed T0785.csv with utf-8 encoding
# Successfully processed T0786.csv with utf-8 encoding
# Successfully processed T0787.csv with utf-8 encoding
# Successfully processed T0788.csv with utf-8 encoding
# Successfully processed T0789.csv with utf-8 encoding
# Successfully processed T0790.csv with utf-8 encoding
# Successfully processed T0791.csv with utf-8 encoding
# Successfully processed T0792.csv with utf-8 encoding
# Successfully processed T0793.csv with utf-8 encoding
# Successfully processed T0794.csv with utf-8 encoding
# Successfully processed T0795.csv with utf-8 encoding
# Successfully processed T0796.csv with utf-8 encoding
# Successfully processed T0797.csv with utf-8 encoding
# Successfully processed T0798.csv with utf-8 encoding
# Successfully processed T0799.csv with utf-8 encoding
# Successfully processed T0800.csv with utf-8 encoding
# Successfully processed T0801.csv with utf-8 encoding
# Successfully processed T0802.csv with utf-8 encoding
# Successfully processed T0803.csv with utf-8 encoding
# Successfully processed T0804.csv with utf-8 encoding
# Successfully processed T0805.csv with utf-8 encoding
# Successfully processed T0806.csv with utf-8 encoding
# Successfully processed T0807.csv with utf-8 encoding
# Successfully processed T0808.csv with utf-8 encoding
# Successfully processed T0809.csv with utf-8 encoding
# Successfully processed T0810.csv with utf-8 encoding
# Successfully processed T0811.csv with utf-8 encoding
# Successfully processed T0812.csv with utf-8 encoding
# Successfully processed T0813.csv with utf-8 encoding
# Successfully processed T0814.csv with utf-8 encoding
# Successfully processed T0815.csv with utf-8 encoding
# Successfully processed T0816.csv with utf-8 encoding
# Successfully processed T0817.csv with utf-8 encoding
# Successfully processed T0818.csv with utf-8 encoding
# Successfully processed T0819.csv with utf-8 encoding
# Successfully processed T0820.csv with utf-8 encoding
# Successfully processed T0821.csv with utf-8 encoding
# Successfully processed T0822.csv with utf-8 encoding
# Successfully processed T0823.csv with utf-8 encoding
# Successfully processed T0824.csv with utf-8 encoding
# Successfully processed T0825.csv with utf-8 encoding
# Successfully processed T0826.csv with utf-8 encoding
# Successfully processed T0827.csv with utf-8 encoding
# Successfully processed T0828.csv with utf-8 encoding
# Successfully processed T0829.csv with utf-8 encoding
# Successfully processed T0830.csv with utf-8 encoding
# Successfully processed T0831.csv with utf-8 encoding
# Successfully processed T0832.csv with utf-8 encoding
# Successfully processed T0833.csv with utf-8 encoding
# Successfully processed T0834.csv with utf-8 encoding
# Successfully processed T0835.csv with utf-8 encoding
# Successfully processed T0836.csv with utf-8 encoding
# Successfully processed T0837.csv with utf-8 encoding
# Successfully processed T0838.csv with utf-8 encoding
# Successfully processed T0839.csv with utf-8 encoding
# Successfully processed T0840.csv with utf-8 encoding
# Successfully processed T0841.csv with utf-8 encoding
# Successfully processed T0842.csv with utf-8 encoding
# Successfully processed T0843.csv with utf-8 encoding
# Successfully processed T0844.csv with utf-8 encoding
# Successfully processed T0845.csv with utf-8 encoding
# Successfully processed T0846.csv with utf-8 encoding
# Successfully processed T0847.csv with utf-8 encoding
# Successfully processed T0848.csv with utf-8 encoding
# Successfully processed T0849.csv with utf-8 encoding
# Successfully processed T0850.csv with utf-8 encoding
# Successfully processed T0851.csv with utf-8 encoding
# Successfully processed T0852.csv with utf-8 encoding
# Successfully processed T0853.csv with utf-8 encoding
# Successfully processed T0854.csv with utf-8 encoding
# Successfully processed T0855.csv with utf-8 encoding
# Successfully processed T0856.csv with utf-8 encoding
# Successfully processed T0857.csv with utf-8 encoding
# Successfully processed T0858.csv with utf-8 encoding
# Successfully processed T0859.csv with utf-8 encoding
# Successfully processed T0860.csv with utf-8 encoding
# Successfully processed T0861.csv with utf-8 encoding
# Successfully processed T0862.csv with utf-8 encoding
# Successfully processed T0863.csv with utf-8 encoding
# Successfully processed T0864.csv with utf-8 encoding
# Successfully processed T0865.csv with utf-8 encoding
# Successfully processed T0866.csv with utf-8 encoding
# Successfully processed T0867.csv with utf-8 encoding
# Successfully processed T0868.csv with utf-8 encoding
# Successfully processed T0869.csv with utf-8 encoding
# Successfully processed T0870.csv with utf-8 encoding
# Successfully processed T0871.csv with utf-8 encoding
# Successfully processed T0872.csv with utf-8 encoding
# Successfully processed T0873.csv with utf-8 encoding
# Successfully processed T0874.csv with utf-8 encoding
# Successfully processed T0875.csv with utf-8 encoding
# Successfully processed T0876.csv with utf-8 encoding
# Successfully processed T0877.csv with utf-8 encoding
# Successfully processed T0878.csv with utf-8 encoding
# Successfully processed T0879.csv with utf-8 encoding
# Successfully processed T0880.csv with utf-8 encoding
# Successfully processed T0881.csv with utf-8 encoding
# Successfully processed T0882.csv with utf-8 encoding
# Successfully processed T0883.csv with utf-8 encoding
# Successfully processed T0884.csv with utf-8 encoding
# Successfully processed T0885.csv with utf-8 encoding
# Successfully processed T0886.csv with utf-8 encoding
# Successfully processed T0887.csv with utf-8 encoding
# Successfully processed T0888.csv with utf-8 encoding
# Successfully processed T0889.csv with utf-8 encoding
# Successfully processed T0890.csv with utf-8 encoding
# Successfully processed T0891.csv with utf-8 encoding
# Successfully processed T0892.csv with utf-8 encoding
# Successfully processed T0893.csv with utf-8 encoding
# Successfully processed T0894.csv with utf-8 encoding
# Successfully processed T0895.csv with utf-8 encoding
# Successfully processed T0896.csv with utf-8 encoding
# Successfully processed T0897.csv with utf-8 encoding
# Successfully processed T0898.csv with utf-8 encoding
# Successfully processed T0899.csv with utf-8 encoding
# Successfully processed T0900.csv with utf-8 encoding
# Successfully processed T0901.csv with utf-8 encoding
# Successfully processed T0902.csv with utf-8 encoding
# Successfully processed T0903.csv with utf-8 encoding
# Successfully processed T0904.csv with utf-8 encoding
# Successfully processed T0905.csv with utf-8 encoding
# Successfully processed T0906.csv with utf-8 encoding
# Successfully processed T0907.csv with utf-8 encoding
# Successfully processed T0908.csv with utf-8 encoding
# Successfully processed T0909.csv with utf-8 encoding
# Successfully processed T0910.csv with utf-8 encoding
# Successfully processed T0911.csv with utf-8 encoding
# Successfully processed T0912.csv with utf-8 encoding
# Successfully processed T0913.csv with utf-8 encoding
# Successfully processed T0914.csv with utf-8 encoding
# Successfully processed T0915.csv with utf-8 encoding
# Successfully processed T0916.csv with utf-8 encoding
# Successfully processed T0917.csv with utf-8 encoding
# Successfully processed T0918.csv with utf-8 encoding
# Successfully processed T0919.csv with utf-8 encoding
# Successfully processed T0920.csv with utf-8 encoding
# Successfully processed T0921.csv with utf-8 encoding
# Successfully processed T0922.csv with utf-8 encoding
# Successfully processed T0923.csv with utf-8 encoding
# Successfully processed T0924.csv with utf-8 encoding
# Successfully processed T0925.csv with utf-8 encoding
# Successfully processed T0926.csv with utf-8 encoding
# Successfully processed T0927.csv with utf-8 encoding
# Successfully processed T0928.csv with utf-8 encoding
# Successfully processed T0929.csv with utf-8 encoding
# Successfully processed T0930.csv with utf-8 encoding
# Successfully processed T0931.csv with utf-8 encoding
# Successfully processed T0932.csv with utf-8 encoding
# Successfully processed T0933.csv with utf-8 encoding
# Successfully processed T0934.csv with utf-8 encoding
# Successfully processed T0935.csv with utf-8 encoding
# Successfully processed T0936.csv with utf-8 encoding
# Successfully processed T0937.csv with utf-8 encoding
# Successfully processed T0938.csv with utf-8 encoding
# Successfully processed T0939.csv with utf-8 encoding
# Successfully processed T0940.csv with utf-8 encoding
# Successfully processed T0941.csv with utf-8 encoding
# Successfully processed T0942.csv with utf-8 encoding
# Successfully processed T0943.csv with utf-8 encoding
# Successfully processed T0944.csv with utf-8 encoding
# Successfully processed T0945.csv with utf-8 encoding
# Successfully processed T0946.csv with utf-8 encoding
# Successfully processed T0947.csv with utf-8 encoding
# Successfully processed T0948.csv with utf-8 encoding
# Successfully processed T0949.csv with utf-8 encoding
# Successfully processed T0950.csv with utf-8 encoding
# Successfully processed T0951.csv with utf-8 encoding
# Successfully processed T0952.csv with utf-8 encoding
# Successfully processed T0953.csv with utf-8 encoding
# Successfully processed T0954.csv with utf-8 encoding
# Successfully processed T0955.csv with utf-8 encoding
# Successfully processed T0956.csv with utf-8 encoding
# Successfully processed T0957.csv with utf-8 encoding
# Successfully processed T0958.csv with utf-8 encoding
# Successfully processed T0959.csv with utf-8 encoding
# Successfully processed T0960.csv with utf-8 encoding
# Successfully processed T0961.csv with utf-8 encoding
# Successfully processed T0962.csv with utf-8 encoding
# Successfully processed T0963.csv with utf-8 encoding
# Successfully processed T0964.csv with utf-8 encoding
# Successfully processed T0965.csv with utf-8 encoding
# Successfully processed T0966.csv with utf-8 encoding
# Successfully processed T0967.csv with utf-8 encoding
# Successfully processed T0968.csv with utf-8 encoding
# Successfully processed T0969.csv with utf-8 encoding
# Successfully processed T0970.csv with utf-8 encoding
# Successfully processed T0971.csv with utf-8 encoding
# Successfully processed T0972.csv with utf-8 encoding
# Successfully processed T0973.csv with utf-8 encoding
# Successfully processed T0974.csv with utf-8 encoding
# Successfully processed T0975.csv with utf-8 encoding
# Successfully processed T0976.csv with utf-8 encoding
# Successfully processed T0977.csv with utf-8 encoding
# Successfully processed T0978.csv with utf-8 encoding
# Successfully processed T0979.csv with utf-8 encoding
# Successfully processed T0980.csv with utf-8 encoding
# Successfully processed T0981.csv with utf-8 encoding
# Successfully processed T0982.csv with utf-8 encoding
# Successfully processed T0983.csv with utf-8 encoding
# Successfully processed T0984.csv with utf-8 encoding
# Successfully processed T0985.csv with utf-8 encoding
# Successfully processed T0986.csv with utf-8 encoding
# Successfully processed T0987.csv with utf-8 encoding
# Successfully processed T0988.csv with utf-8 encoding
# Successfully processed T0989.csv with utf-8 encoding
# Successfully processed T0990.csv with utf-8 encoding
# Successfully processed T0991.csv with utf-8 encoding
# Successfully processed T0992.csv with utf-8 encoding
# Successfully processed T0993.csv with utf-8 encoding
# Successfully processed T0994.csv with utf-8 encoding
# Successfully processed T0995.csv with utf-8 encoding
# Successfully processed T0996.csv with utf-8 encoding
# Successfully processed T0997.csv with utf-8 encoding
# Successfully processed T0998.csv with utf-8 encoding
# Successfully processed T0999.csv with utf-8 encoding
# Successfully processed T1000.csv with utf-8 encoding
# Successfully processed T1001.csv with utf-8 encoding
# Successfully processed T1002.csv with utf-8 encoding
# Successfully processed T1003.csv with utf-8 encoding
# Successfully processed T1004.csv with utf-8 encoding
# Successfully processed T1005.csv with utf-8 encoding
# Successfully processed T1006.csv with utf-8 encoding
# Successfully processed T1007.csv with utf-8 encoding
# Successfully processed T1008.csv with utf-8 encoding
# Successfully processed T1009.csv with utf-8 encoding
# Successfully processed T1010.csv with utf-8 encoding
# Successfully processed T1011.csv with utf-8 encoding
# Successfully processed T1012.csv with utf-8 encoding
# Successfully processed T1013.csv with utf-8 encoding
# Successfully processed T1014.csv with utf-8 encoding
# Successfully processed T1015.csv with utf-8 encoding
# Successfully processed T1016.csv with utf-8 encoding
# Successfully processed T1017.csv with utf-8 encoding
# Successfully processed T1018.csv with utf-8 encoding
# Successfully processed T1019.csv with utf-8 encoding
# Successfully processed T1020.csv with utf-8 encoding
# Successfully processed T1021.csv with utf-8 encoding
# Successfully processed T1022.csv with utf-8 encoding
# Successfully processed T1023.csv with utf-8 encoding
# Successfully processed T1024.csv with utf-8 encoding
# Successfully processed T1025.csv with utf-8 encoding
# Successfully processed T1026.csv with utf-8 encoding
# Successfully processed T1027.csv with utf-8 encoding
# Successfully processed T1028.csv with utf-8 encoding
# Successfully processed T1029.csv with utf-8 encoding
# Successfully processed T1030.csv with utf-8 encoding
# Successfully processed T1031.csv with utf-8 encoding
# Successfully processed T1032.csv with utf-8 encoding
# Successfully processed T1033.csv with utf-8 encoding
# Successfully processed T1034.csv with utf-8 encoding
# Successfully processed T1035.csv with utf-8 encoding
# Successfully processed T1036.csv with utf-8 encoding
# Successfully processed T1037.csv with utf-8 encoding
# Successfully processed T1038.csv with utf-8 encoding
# Successfully processed T1039.csv with utf-8 encoding
# Successfully processed T1040.csv with utf-8 encoding
# Successfully processed T1041.csv with utf-8 encoding
# Successfully processed T1042.csv with utf-8 encoding
# Successfully processed T1043.csv with utf-8 encoding
# Successfully processed T1044.csv with utf-8 encoding
# Successfully processed T1045.csv with utf-8 encoding
# Successfully processed T1046.csv with utf-8 encoding
# Successfully processed T1047.csv with utf-8 encoding
# Successfully processed T1048.csv with utf-8 encoding
# Successfully processed T1049.csv with utf-8 encoding
# Successfully processed T1050.csv with utf-8 encoding
# Successfully processed T1051.csv with utf-8 encoding
# Successfully processed T1052.csv with utf-8 encoding
# Successfully processed T1053.csv with utf-8 encoding
# Successfully processed T1054.csv with utf-8 encoding
# Successfully processed T1055.csv with utf-8 encoding
# Successfully processed T1056.csv with utf-8 encoding
# Successfully processed T1057.csv with utf-8 encoding
# Successfully processed T1058.csv with utf-8 encoding
# Successfully processed T1059.csv with utf-8 encoding
# Successfully processed T1060.csv with utf-8 encoding
# Successfully processed T1061.csv with utf-8 encoding
# Successfully processed T1062.csv with utf-8 encoding
# Successfully processed T1063.csv with utf-8 encoding
# Successfully processed T1064.csv with utf-8 encoding
# Successfully processed T1065.csv with utf-8 encoding
# Successfully processed T1066.csv with utf-8 encoding
# Successfully processed T1067.csv with utf-8 encoding
# Successfully processed T1068.csv with utf-8 encoding
# Successfully processed T1069.csv with utf-8 encoding
# Successfully processed T1070.csv with utf-8 encoding
# Successfully processed T1071.csv with utf-8 encoding
# Successfully processed T1072.csv with utf-8 encoding
# Successfully processed T1073.csv with utf-8 encoding
# Successfully processed T1074.csv with utf-8 encoding
# Successfully processed T1075.csv with utf-8 encoding
# Successfully processed T1076.csv with utf-8 encoding
# Successfully processed T1077.csv with utf-8 encoding
# Successfully processed T1078.csv with utf-8 encoding
# Successfully processed T1079.csv with utf-8 encoding
# Successfully processed T1080.csv with utf-8 encoding
# Successfully processed T1081.csv with utf-8 encoding
# Successfully processed T1082.csv with utf-8 encoding
# Successfully processed T1083.csv with utf-8 encoding
# Successfully processed T1084.csv with utf-8 encoding
# Successfully processed T1085.csv with utf-8 encoding
# Successfully processed T1086.csv with utf-8 encoding
# Successfully processed T1087.csv with utf-8 encoding
# Successfully processed T1088.csv with utf-8 encoding
# Successfully processed T1089.csv with utf-8 encoding
# Successfully processed T1090.csv with utf-8 encoding
# Successfully processed T1091.csv with utf-8 encoding
# Successfully processed T1092.csv with utf-8 encoding
# Successfully processed T1093.csv with utf-8 encoding
# Successfully processed T1094.csv with utf-8 encoding
# Successfully processed T1095.csv with utf-8 encoding
# Successfully processed T1096.csv with utf-8 encoding
# Successfully processed T1097.csv with utf-8 encoding
# Successfully processed T1098.csv with utf-8 encoding
# Successfully processed T1099.csv with utf-8 encoding
# Successfully processed T1100.csv with utf-8 encoding
# Successfully processed T1101.csv with utf-8 encoding
# Successfully processed T1102.csv with utf-8 encoding
# Successfully processed T1103.csv with utf-8 encoding
# Successfully processed T1104.csv with utf-8 encoding
# Successfully processed T1105.csv with utf-8 encoding
# Successfully processed T1106.csv with utf-8 encoding
# Successfully processed T1107.csv with utf-8 encoding
# Successfully processed T1108.csv with utf-8 encoding
# Successfully processed T1109.csv with utf-8 encoding
# Successfully processed T1110.csv with utf-8 encoding
# Successfully processed T1111.csv with utf-8 encoding
# Successfully processed T1112.csv with utf-8 encoding
# Successfully processed T1113.csv with utf-8 encoding
# Successfully processed T1114.csv with utf-8 encoding
# Successfully processed T1115.csv with utf-8 encoding
# Successfully processed T1116.csv with utf-8 encoding
# Successfully processed T1117.csv with utf-8 encoding
# Successfully processed T1118.csv with utf-8 encoding
# Successfully processed T1119.csv with utf-8 encoding
# Successfully processed T1120.csv with utf-8 encoding
# Successfully processed T1121.csv with utf-8 encoding
# Successfully processed T1122.csv with utf-8 encoding
# Successfully processed T1123.csv with utf-8 encoding
# Successfully processed T1124.csv with utf-8 encoding
# Successfully processed T1125.csv with utf-8 encoding
# Successfully processed T1126.csv with utf-8 encoding
# Successfully processed T1127.csv with utf-8 encoding
# Successfully processed T1128.csv with utf-8 encoding
# Successfully processed T1129.csv with utf-8 encoding
# Successfully processed T1130.csv with utf-8 encoding
# Successfully processed T1131.csv with utf-8 encoding
# Successfully processed T1132.csv with utf-8 encoding
# Successfully processed T1133.csv with utf-8 encoding
# Successfully processed T1134.csv with utf-8 encoding
# Successfully processed T1135.csv with utf-8 encoding
# Successfully processed T1136.csv with utf-8 encoding
# Successfully processed T1137.csv with utf-8 encoding
# Successfully processed T1138.csv with utf-8 encoding
# Successfully processed T1139.csv with utf-8 encoding
# Successfully processed T1140.csv with utf-8 encoding
# Successfully processed T1141.csv with utf-8 encoding
# Successfully processed T1142.csv with utf-8 encoding
# Successfully processed T1143.csv with utf-8 encoding
# Successfully processed T1144.csv with utf-8 encoding
# Successfully processed T1145.csv with utf-8 encoding
# Successfully processed T1146.csv with utf-8 encoding
# Successfully processed T1147.csv with utf-8 encoding
# Successfully processed T1148.csv with utf-8 encoding
# Successfully processed T1149.csv with utf-8 encoding
# Successfully processed T1150.csv with utf-8 encoding
# Successfully processed T1151.csv with utf-8 encoding
# Successfully processed T1152.csv with utf-8 encoding
# Successfully processed T1153.csv with utf-8 encoding
# Successfully processed T1154.csv with utf-8 encoding
# Successfully processed T1155.csv with utf-8 encoding
# Successfully processed T1156.csv with utf-8 encoding
# Successfully processed T1157.csv with utf-8 encoding
# Successfully processed T1158.csv with utf-8 encoding
# Successfully processed T1159.csv with utf-8 encoding
# Successfully processed T1160.csv with utf-8 encoding
# Successfully processed T1161.csv with utf-8 encoding
# Successfully processed T1162.csv with utf-8 encoding
# Successfully processed T1163.csv with utf-8 encoding
# Successfully processed T1164.csv with utf-8 encoding
# Successfully processed T1165.csv with utf-8 encoding
# Successfully processed T1166.csv with utf-8 encoding
# Successfully processed T1167.csv with utf-8 encoding
# Successfully processed T1168.csv with utf-8 encoding
# Successfully processed T1169.csv with utf-8 encoding
# Successfully processed T1170.csv with utf-8 encoding
# Successfully processed T1171.csv with utf-8 encoding
# Successfully processed T1172.csv with utf-8 encoding
# Successfully processed T1173.csv with utf-8 encoding
# Successfully processed T1174.csv with utf-8 encoding
# Successfully processed T1175.csv with utf-8 encoding
# Successfully processed T1176.csv with utf-8 encoding
# Successfully processed T1177.csv with utf-8 encoding
# Successfully processed T1178.csv with utf-8 encoding
# Successfully processed T1179.csv with utf-8 encoding
# Successfully processed T1180.csv with utf-8 encoding
# Successfully processed T1181.csv with utf-8 encoding
# Successfully processed T1182.csv with utf-8 encoding
# Successfully processed T1183.csv with utf-8 encoding
# Successfully processed T1184.csv with utf-8 encoding
# Successfully processed T1185.csv with utf-8 encoding
# Successfully processed T1186.csv with utf-8 encoding
# Successfully processed T1187.csv with utf-8 encoding
# Successfully processed T1188.csv with utf-8 encoding
# Successfully processed T1189.csv with utf-8 encoding
# Successfully processed T1190.csv with utf-8 encoding
# Successfully processed T1191.csv with utf-8 encoding
# Successfully processed T1192.csv with utf-8 encoding
# Successfully processed T1193.csv with utf-8 encoding
# Successfully processed T1194.csv with utf-8 encoding
# Successfully processed T1195.csv with utf-8 encoding
# Successfully processed T1196.csv with utf-8 encoding
# Successfully processed T1197.csv with utf-8 encoding
# Successfully processed T1198.csv with utf-8 encoding
# Successfully processed T1199.csv with utf-8 encoding
# Successfully processed T1200.csv with utf-8 encoding
# Error processing metadata_tabel.csv: 'Kecamatan'

# %%
import json

def view_json_file(file_path):
    """
    Membuka dan menampilkan isi file JSON.

    Args:
        file_path: Path ke file JSON yang ingin dibuka.
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)

        print(json.dumps(data, indent=4, ensure_ascii=False))  # Menampilkan data dengan indentasi

    except FileNotFoundError:
        print(f"File tidak ditemukan: {file_path}")
    except json.JSONDecodeError:
        print(f"File bukan JSON yang valid: {file_path}")
    except Exception as e:
        print(f"Terjadi kesalahan: {e}")

# %%
file_path = 'C:/Users/ASUS/OneDrive - Politeknik Statistika STIS/Dokumen/KULIAH/SEMESTER 7/[2] SKRIPSI/[4] PENGOLAHAN/Generate Descriptions Version 2/base_tambahan_reasoning/T0234.json'
view_json_file(file_path)
# Out:
# {
#     "T0234": {
#         "metadata": {
#             "title": "Kepadatan Penduduk",
#             "unit": "jiwa/km²",
#             "year": 2015
#         },
#         "base_description": "Dengan demikian, Kecamatan Klojen memiliki Kepadatan Penduduk tertinggi sebesar 11.792 jiwa/km², sedangkan Kecamatan Kedungkandang memiliki nilai terendah sebesar 4.665 jiwa/km² di Kota Malang."
#     }
# }
